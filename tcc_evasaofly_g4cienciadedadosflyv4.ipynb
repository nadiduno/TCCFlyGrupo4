# %% [markdown]
# <a href="https://colab.research.google.com/github/nadiduno/TCCFlyGrupo4/blob/main/tcc_evasaofly_g4cienciadedadosflyv4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Ada Lovelace - Turma Fly · diversiData
#
# > 🗺️ **Autoras:** [Brenda Amaral](https://www.linkedin.com/in/brendaamarals/), [Fernanda da Silva](https://www.linkedin.com/in/fernanda-leticia-silva/), [Nadiveth Duno](https://www.linkedin.com/in/nadiduno/), Profana Buzato, [Sheilliane Santos](https://www.linkedin.com/in/sheillianesantos/), [Vicencia Vitória Souza](www.linkedin.com/in/vicencia-vitoria).
#
# > 🗺️**Orientadora:** [Andressa Freires](https://www.linkedin.com/in/andressafreires/)

# %% [markdown]
# Um modelo preditivo de potencial de empregabilidade e mobilidade financeira para egressos da Fly Educação

# %% [markdown]
# ---
# # 📥 1. Carregar os dados

# %%
# !pip install missingno gdown pyarrow openpyxl -q
print("Pacotes instalados!")
# Out:
# Pacotes instalados!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from google.colab import files
import warnings
import urllib.parse
import sys
import os
import unicodedata

warnings.filterwarnings('ignore')
print('Importação com sucesso!')
print(f"pandas {pd.__version__}, numpy {np.__version__}, seaborn {sns.__version__}")
# Out:
# Importação com sucesso!
# pandas 2.2.3, numpy 2.1.3, seaborn 0.13.2

# %%
sheet_id = "1y0cfHPKjqp75TlMEzBdOMVuifPB_P__P"
abas = {"T10_11_14_15_17": "P1_turmas_10_11_14_15_17","T12": "P2_turma_12","T16": "P3_turma_16","T18": "P4_turma_18","T19": "P5_turma_19","T20": "P6_turma_20","T22": "P7_turma_22","T23": "P9_turma_23",}
dataFlyTurmas = {}

for aba, planilha_id in abas.items():
    nome_codificado = urllib.parse.quote(aba)
    url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={nome_codificado}"
    try:
        df = pd.read_csv(url)
        df["turma_aba"] = aba
        dataFlyTurmas[aba] = df
        #print(f"{aba}-> {df.shape[0]} linhas, {df.shape[1]} colunas")
    except Exception as e:
        print(f"{aba}: ERRO -> {e}")
print("Dados carregados com sucesso")
# Out:
# Dados carregados com sucesso

# %%
#dataFlyTurmas["T10_11_14_15_17"].head(3)

# %% [markdown]
# ## Usar script para renomear colunas
#
# ---

# %%
# Baixar Script de Pythom com novos nomes para as colunas  renameCols_maps.py (id 10VCq_huDlCFg7y9QGbLosQnwAU0fmzoe)
# !gdown 10VCq_huDlCFg7y9QGbLosQnwAU0fmzoe
from renameCols_maps import rename_maps
# !ls -la *.py
print("Script executado")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=10VCq_huDlCFg7y9QGbLosQnwAU0fmzoe
# From (redirected): https://drive.google.com/uc?id=10VCq_huDlCFg7y9QGbLosQnwAU0fmzoe&confirm=t&uuid=4e96514f-69fb-4686-b6e5-5bee76cf8b4c
# To: /content/renameCols_maps.py
# 100% 38.5k/38.5k [00:00<00:00, 55.0MB/s]
# -rw-r--r-- 1 root root 38535 Aug  9 04:38 renameCols_maps.py
# Script executado

# %%
# Renomeando as colunas usando o Script
dataFlyRenamed = {}

for aba, df in dataFlyTurmas.items():
    df_r = df.rename(columns=rename_maps[aba])
    dataFlyRenamed[aba] = df_r
    # checagem: coluna renomeada
    nao_renomeadas = [c for c in df_r.columns if c in rename_maps[aba].values()][:0]  # placeholder
    cols_originais_restantes = set(df.columns) & set(df_r.columns)  # nomes que sobreviveram sem mudar
print("As colunas foram renomeadas conforme o novo mapeamento")
# Out:
# As colunas foram renomeadas conforme o novo mapeamento

# %%
# Empilhar abas com as MESMAS colunas em um novo DataFRame
if dataFlyRenamed:
    dataFlyJoin = pd.concat(dataFlyRenamed.values(),ignore_index=True,sort=False)
else:
    dataFlyJoin = pd.DataFrame() # Initialize as an empty DataFrame if no data to concatenate
    print("Advertencia: dataFlyRenamed está vacío. dataFlyJoin se ha inicializado como un DataFrame vacío.")
print(f"Abas unificadas: {dataFlyJoin.shape[0]} linhas, {dataFlyJoin.shape[1]} colunas")
# Out:
# Abas unificadas: 2348 linhas, 91 colunas

# %%
#dataFlyJoin.info()

# %% [markdown]
# ## Salvar e usar Parquet

# %%
dataFlyJoin['idade'] = pd.to_numeric(dataFlyJoin['idade'], errors='coerce').astype('Int64')
dataFlyJoin['qtd_pessoas_casa'] = pd.to_numeric(dataFlyJoin['qtd_pessoas_casa'], errors='coerce').round().astype('Int64')
dataFlyJoin['data_nascimento'] = pd.to_datetime(dataFlyJoin['data_nascimento'], errors='coerce')

dataFlyJoin.to_csv('dataFlyRaw.csv', index=False, encoding='utf-8-sig')
dataFlyJoin.to_parquet('dataFlyRaw.parquet', index=False)
print("Arquivo CSV e Parquet salvos com sucesso - Data Raw!")
# Out:
# Arquivo CSV e Parquet salvos com sucesso - Data Raw!

# %%
dataFlyRaw = pd.read_parquet('dataFlyRaw.parquet')
dataFlyRaw.to_parquet('dataFlyRaw.parquet', index=False, compression='gzip')

# %%
#dataFlyRaw.to_csv('dataFlyRaw.csv', index=False, encoding='utf-8-sig')
#files.download('dataFlyRaw.csv')
#files.download('dataFlyRaw.parquet')
#print("Descarga concluida!")

# %% [markdown]
# ---
# # 🔍 2. Conhecer os dados (o raio-x)

# %% [markdown]
# ## Shape-Head-Describe

# %%
# (linhas, colunas) → tem o tamanho que você esperava?
dataFlyRaw.shape
# Out:
# (2348, 91)

# %%
# A "cara" dos dados
dataFlyRaw.head(3)
# Out:
#   nome_completo status_aprovacao      genero lgbtqia raca_etnia  idade  pcd  \
# 0       Aluna 1         Formadas  Mulher Cis     Sim      Preta     22  Não
# 1       Aluna 2     Não aprovada  Mulher Cis     Não      Parda      0  Não
# 2       Aluna 3    Não aprovadas  Mulher Cis     Não      Parda     45  Não
#
#   pcd_tipo pcd_impacto_aprendizagem                          escolaridade  \
# 0     None                     None  Ensino Superior Completo (Graduação)
# 1     None                     None                 Ensino Médio Completo
# 2     None                      Não                 Ensino Médio Completo
#
#    ... experiencia_programacao linguagem_programacao experiencia_dados  \
# 0  ...                    None                  None              None
# 1  ...                    None                  None              None
# 2  ...                    None                  None              None
#
#   dataset_inconsistente_acao bibliotecas_ferramentas_utilizadas  \
# 0                       None                               None
# 1                       None                               None
# 2                       None                               None
#
#    git_github_uso link_projeto_perfil projeto_dados_ia_descricao  \
# 0            None                None                       None
# 1            None                None                       None
# 2            None                None                       None
#
#   dataset_evasao_interpretacao leitura_edital
# 0                         None           None
# 1                         None           None
# 2                         None           None
#
# [3 rows x 91 columns]

# %%
# Tipos das colunas → número está como número? (não como 'object')
dataFlyRaw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2348 entries, 0 to 2347
# Data columns (total 91 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   nome_completo                            2348 non-null   object
#  1   status_aprovacao                         1170 non-null   object
#  2   genero                                   2229 non-null   object
#  3   lgbtqia                                  2228 non-null   object
#  4   raca_etnia                               2347 non-null   object
#  5   idade                                    1975 non-null   Int64
#  6   pcd                                      2222 non-null   object
#  7   pcd_tipo                                 862 non-null    object
#  8   pcd_impacto_aprendizagem                 211 non-null    object
#  9   escolaridade                             2347 non-null   object
#  10  estado_residencia                        2162 non-null   object
#  11  cidade_residencia                        1426 non-null   object
#  12  como_conheceu_mulheres_in_tech           1153 non-null   object
#  13  processo_seletivo_anterior               540 non-null    object
#  14  processo_seletivo_anterior_detalhe       1 non-null      object
#  15  qtd_pessoas_casa                         1642 non-null   Int64
#  16  renda_familiar_pessoa                    2347 non-null   object
#  17  renda_propria                            1205 non-null   object
#  18  renda_principal_fonte_casa               1186 non-null   object
#  19  situacao_profissional_atual              1655 non-null   object
#  20  situacao_financeira_casa                 1529 non-null   object
#  21  interesse_dev_web                        641 non-null    object
#  22  possui_computador                        1470 non-null   object
#  23  possui_wifi                              630 non-null    object
#  24  disponibilidade_quarta_noite             513 non-null    object
#  25  disponibilidade_mentoria_semanal         513 non-null    object
#  26  disponibilidade_tempo_estudo             1530 non-null   object
#  27  turma                                    1205 non-null   object
#  28  coluna_vazia                             0 non-null      float64
#  29  turma_aba                                2348 non-null   object
#  30  refugiada_imigrante                      301 non-null    object
#  31  refugiada_pais                           144 non-null    object
#  32  interesse_ia_gestao                      117 non-null    object
#  33  justificativa_interesse                  177 non-null    object
#  34  expectativa_mentoria                     1017 non-null   object
#  35  percepcao_pedir_ajuda                    1017 non-null   object
#  36  experiencia_autodidata                   1017 non-null   object
#  37  experiencia_positiva_conclusao           1017 non-null   object
#  38  experiencia_negativa_nao_conclusao       1017 non-null   object
#  39  diferenca_entre_experiencias             1016 non-null   object
#  40  confianca_concluir_programa              1017 non-null   object
#  41  rotina_semanal_descricao                 1017 non-null   object
#  42  encaixe_horas_estudo_rotina              1017 non-null   object
#  43  motivo_escolha_candidata                 1017 non-null   object
#  44  compromisso_criterios_certificado        1132 non-null   object
#  45  ciencia_investimento_vaga                1142 non-null   object
#  46  doacao_mensal_voluntaria                 1017 non-null   object
#  47  email                                    1 non-null      object
#  48  coluna_sem_nome                          547 non-null    float64
#  49  orientacao_sexual                        840 non-null    object
#  50  refugiada                                840 non-null    object
#  51  conhecimento_probabilidade               388 non-null    object
#  52  evidencia_conhecimento_probabilidade     206 non-null    object
#  53  conhecimento_estatistica                 388 non-null    object
#  54  evidencia_conhecimento_estatistica       181 non-null    object
#  55  conhecimento_algebra_linear              388 non-null    object
#  56  evidencia_conhecimento_algebra_linear    148 non-null    object
#  57  possui_internet                          840 non-null    object
#  58  conhecimento_ia                          324 non-null    object
#  59  evidencia_conhecimento_ia                196 non-null    object
#  60  filhos_cuidadora                         287 non-null    object
#  61  regiao_residencia                        128 non-null    object
#  62  evidencia_conhecimento_dev_web           64 non-null     object
#  63  data_nascimento                          182 non-null    datetime64[ns]
#  64  nacionalidade                            185 non-null    object
#  65  estado_civil                             60 non-null     object
#  66  endereco_completo                        184 non-null    object
#  67  profissao                                60 non-null     object
#  68  pcd_necessita_adaptacao                  3 non-null      object
#  69  estado_nascimento                        60 non-null     object
#  70  relacao_breu_branco                      60 non-null     object
#  71  como_conheceu_mulheres_in_tech_como_foi  47 non-null     object
#  72  relacao_marketing_digital                60 non-null     object
#  73  dispositivos_disponiveis                 185 non-null    object
#  74  forma_acesso_internet                    60 non-null     object
#  75  situacao_carreira_atual                  60 non-null     object
#  76  apoio_politicas_publicas                 60 non-null     object
#  77  interrupcao_estudos                      60 non-null     object
#  78  ocupacao                                 124 non-null    object
#  79  tipo_escola_formacao                     125 non-null    object
#  80  disponibilidade_tempo_curso              125 non-null    object
#  81  experiencia_programacao                  125 non-null    object
#  82  linguagem_programacao                    120 non-null    object
#  83  experiencia_dados                        125 non-null    object
#  84  dataset_inconsistente_acao               124 non-null    object
#  85  bibliotecas_ferramentas_utilizadas       125 non-null    object
#  86  git_github_uso                           125 non-null    object
#  87  link_projeto_perfil                      119 non-null    object
#  88  projeto_dados_ia_descricao               123 non-null    object
#  89  dataset_evasao_interpretacao             87 non-null     object
#  90  leitura_edital                           124 non-null    object
# dtypes: Int64(2), datetime64[ns](1), float64(2), object(86)
# memory usage: 1.6+ MB

# %%
# Resumo dos números → tem mínimo/máximo impossível? (outliers)
dataFlyRaw.describe()
# Out:
#                idade  qtd_pessoas_casa  coluna_vazia  coluna_sem_nome  \
# count         1975.0            1642.0           0.0       547.000000
# mean    13744.847089          6.478685           NaN        69.837294
# min              0.0               0.0           NaN         1.000000
# 25%             24.0               2.0           NaN        21.000000
# 50%             31.0               3.0           NaN        46.000000
# 75%             40.0               4.0           NaN       101.500000
# max       27081982.0            2000.0           NaN       233.000000
# std    609391.475144         71.589406           NaN        63.065065
#
#                      data_nascimento
# count                            182
# mean   1985-10-06 02:06:35.604396864
# min              1966-08-07 00:00:00
# 25%    1970-01-01 00:00:00.000000041
# 50%              1986-09-24 12:00:00
# 75%              1997-04-13 18:00:00
# max              2024-07-09 00:00:00
# std                              NaN

# %%
# Quantos VAZIOS por coluna → onde precisa tratar?
dataFlyRaw.isnull().sum()
# Out:
# nome_completo                      0
# status_aprovacao                1178
# genero                           119
# lgbtqia                          120
# raca_etnia                         1
#                                 ...
# git_github_uso                  2223
# link_projeto_perfil             2229
# projeto_dados_ia_descricao      2225
# dataset_evasao_interpretacao    2261
# leitura_edital                  2224
# Length: 91, dtype: int64

# %%
# Quantos valores DIFERENTES por coluna → alguma quase constante?
dataFlyRaw.nunique()
# Out:
# nome_completo                   2348
# status_aprovacao                   6
# genero                            27
# lgbtqia                           14
# raca_etnia                        11
#                                 ...
# git_github_uso                     3
# link_projeto_perfil               94
# projeto_dados_ia_descricao       115
# dataset_evasao_interpretacao      83
# leitura_edital                     1
# Length: 91, dtype: int64

# %%
# O que tem numa categoria → texto repetido escrito diferente?
dataFlyRaw['status_aprovacao'].value_counts()
# Out:
# status_aprovacao
# Não aprovada     545
# Não aprovadas    459
# Formadas          53
# Aprovada          53
# Formada           47
# Aprovadas         13
# Name: count, dtype: int64

# %% [markdown]
# ---
# # 🧹 3. Limpar os dados
#
# > **Objetivo:** corrigir os problemas que você achou no passo 2.
# > **Consulte:** notebook da aula de limpeza para exemplos completos.

# %% [markdown]
#  ## Duplicatas

# %%
#dataFlyRaw.drop_duplicates()
n_dup = dataFlyRaw.duplicated().sum()
print(f'📋 Linhas duplicadas: {n_dup:,} ({n_dup/len(dataFlyRaw)*100:.1f}%)')
print()
print('Exemplo de duplicata (as mesmas linhas aparecem duas vezes):')
dup_ex = dataFlyRaw[dataFlyRaw.duplicated(keep=False)].sort_values('nome_completo').head(4)
#display(dup_ex[['id_trabalhadora','uf','setor','cargo','salario_mensal','idade']])
#.drop_duplicates() - Apagar as linhas duplicadas
# Out:
# 📋 Linhas duplicadas: 0 (0.0%)
#
# Exemplo de duplicata (as mesmas linhas aparecem duas vezes):

# %%
dataFlyClear =  dataFlyRaw

# %% [markdown]
#  ## Texto padronizado

# %%
def normalizar_texto(texto): # Código reutilizável
    if pd.isna(texto):
        return np.nan
    texto = texto.strip().lower()                        # remove espaços, minúsculo
    texto = unicodedata.normalize('NFKD', texto)         # decompõe acentos
    texto = ''.join(c for c in texto                     # remove os acentos
                    if not unicodedata.combining(c))
    return texto

# %% [markdown]
# ## Normalização

# %%
print(dataFlyClear['status_aprovacao'].value_counts())
# Out:
# status_aprovacao
# Não aprovada     545
# Não aprovadas    459
# Formadas          53
# Aprovada          53
# Formada           47
# Aprovadas         13
# Name: count, dtype: int64

# %%
# Coluna status_aprovacao
print(dataFlyClear['status_aprovacao'].value_counts())
mask_aprovada = dataFlyClear['status_aprovacao'].str.contains('Aprovada|Aprovadas', na=False)
mask_naoaprovada = dataFlyClear['status_aprovacao'].str.contains('Não aprovada|Não aprovadas', na=False)
mask_formada = dataFlyClear['status_aprovacao'].str.contains('Formada|Formadas', na=False)
#apply = aplicar, aplicando a função na coluna de status de aprovação
dataFlyClear['status_aprovacao'] = dataFlyClear['status_aprovacao'].apply(normalizar_texto)
print(f'\nNormalização "status_aprovacao" feita com sucesso:\n')
# Dicionário de mapeamento para status de aprovacao
mapeamento = {
    'nao aprovada': 'Não aprovada',
    'nao aprovadas': 'Não aprovada',
    'aprovada': 'Aprovada',
    'aprovadas': 'Aprovada',
    'formada': 'Formada',
    'formadas': 'Formada'
}
dataFlyClear['status_aprovacao'] = dataFlyClear['status_aprovacao'].replace(mapeamento)
print('✅ "Aprovada", "Aprovadas" agora são a mesma categoria!\n')
print(dataFlyClear['status_aprovacao'].value_counts())
# Out:
# status_aprovacao
# Não aprovada     545
# Não aprovadas    459
# Formadas          53
# Aprovada          53
# Formada           47
# Aprovadas         13
# Name: count, dtype: int64
#
# Normalização "status_aprovacao" feita com sucesso:
#
# ✅ "Aprovada", "Aprovadas" agora são a mesma categoria!
#
# status_aprovacao
# Não aprovada    1004
# Formada          100
# Aprovada          66
# Name: count, dtype: int64

# %%
#print(dataFlyClear['NOMEDACOLUNAAQUIIIIIII'].value_counts())

print(dataFlyClear['genero'].value_counts())
# Out:
# genero
# Mulher Cis               1311
# Feminino                  832
# Mulher Transgênero         31
# Não-Binário                18
# Mulher Trans                6
# Não-Binárie                 5
# Masculino                   3
# Travesti                    2
# Mulher                      2
# Mulher                      2
# Mulher trans                1
# Femenino                    1
# Outro                       1
# qual                        1
# Mulher hetero               1
# Fêmea por natureza          1
# Mujer heterosexual          1
# Mulher trans                1
# Mulher normal               1
# Prefiro não responder       1
# Hetero                      1
# Heterossexual               1
# Não binário                 1
# Bissexual                   1
# Mulher mesmo                1
# Hétero                      1
# Travesti                    1
# Name: count, dtype: int64

# %%
# Coluna genero
print(dataFlyClear['genero'].value_counts())
mask_mulhercis= dataFlyClear['genero'].str.contains('mulher cis|mulher', na=False)
mask_mulhertrans = dataFlyClear['genero'].str.contains('mulher trans|mulher transgenero', na=False)
mask_naobinário = dataFlyClear['genero'].str.contains('não Binario|não-binarie ', na=False)
#apply = aplicar, aplicando a função na coluna de status de aprovação
dataFlyClear['genero'] = dataFlyClear['genero'].apply(normalizar_texto)
print(f'\nNormalização "genero" feita com sucesso:\n')
# Dicionário de mapeamento para status de aprovacao
mapeamento = {
    'mulher cis': 'Mulher cisgênero',
    'mulher': 'Mulher cisgênero',
    'feminino': 'Mulher cisgênero',
    'femea por natureza': 'Mulher cisgênero',
    'mujer heterosexual': 'Mulher cisgênero',
    'hetero': 'Mulher cisgênero',
    'mulher mesmo': 'Mulher cisgênero',
    'bissexual': 'Mulher cisgênero',
    'mulher normal': 'Mulher cisgênero',
    'mulher hetero': 'Mulher cisgênero',
    'femenino' :'Mulher cisgênero',
    'heterossexual' : 'Mulher cisgênero',

    'mulher trans': 'Mulher Transgênero',
    'mulher transgenero': 'Mulher Transgênero',
    'travesti': 'Mulher Transgênero',
    'masculino' : 'Mulher Transgênero',

    'nao binario': 'Não-Binário',
    'nao-binarie': 'Não-Binário',
    'nao-binario': 'Não-Binário',
    'nao binarie': 'Não-Binário',
    'outro': 'Não-Binário',
    'qual': 'Não-Binário',
    'prefiro nao responder': 'Não-Binário'
}
dataFlyClear['genero'] = dataFlyClear['genero'].replace(mapeamento)
print('✅ "mulher Cis", "mulher" agora são a mesma categoria!\n')
print(dataFlyClear['genero'].value_counts())
# Out:
# genero
# Mulher Cis               1311
# Feminino                  832
# Mulher Transgênero         31
# Não-Binário                18
# Mulher Trans                6
# Não-Binárie                 5
# Masculino                   3
# Travesti                    2
# Mulher                      2
# Mulher                      2
# Mulher trans                1
# Femenino                    1
# Outro                       1
# qual                        1
# Mulher hetero               1
# Fêmea por natureza          1
# Mujer heterosexual          1
# Mulher trans                1
# Mulher normal               1
# Prefiro não responder       1
# Hetero                      1
# Heterossexual               1
# Não binário                 1
# Bissexual                   1
# Mulher mesmo                1
# Hétero                      1
# Travesti                    1
# Name: count, dtype: int64
#
# Normalização "genero" feita com sucesso:
#
# ✅ "mulher Cis", "mulher" agora são a mesma categoria!
#
# genero
# Mulher cisgênero      2157
# Mulher Transgênero      45
# Não-Binário             27
# Name: count, dtype: int64

# %%
print(dataFlyClear['lgbtqia'].value_counts())
# Out:
# lgbtqia
# Não                                                                               1558
# Sim                                                                                646
# Prefiro não responder                                                               12
# Simpatizante                                                                         2
# Prefiro não dizer                                                                    1
# Simpatizante e respeito as suas escolhas                                             1
# Prefiro não responder                                                                1
# Prefiro não falar                                                                    1
# Acredito da liberdade de genero mas nao participo                                    1
# Não sei                                                                              1
# digamos, eu sou, mas tenho renunciado por causa da minha fé.                         1
# Respeito a todos e tenho amigos na comunidade, mais sou mulher.                      1
# No formulário não há pergunta sobre deficiência: tenho TEA nível  1 de suporte       1
# Sou Bi, isso inclui??                                                                1
# Name: count, dtype: int64

# %%
print(dataFlyClear['lgbtqia'].value_counts())
mask_nao = dataFlyClear['lgbtqia'].str.contains('nao participo|mais sou mulher|^nao$', na=False, case=False)
mask_sim = dataFlyClear['lgbtqia'].str.contains('sim|simpatizante|renunciado|sou bi', na=False, case=False)
mask_prefiro = dataFlyClear['lgbtqia'].str.contains('prefiro|nao sei|deficiencia|tea', na=False, case=False)


dataFlyClear.loc[mask_nao, 'lgbtqia'] = 'Não'
dataFlyClear.loc[mask_sim, 'lgbtqia'] = 'Sim'
dataFlyClear.loc[mask_prefiro, 'lgbtqia'] = 'Prefiro não responder'


#apply = aplicar, aplicando a função na coluna de status de aprovação
dataFlyClear['lgbtqia'] = dataFlyClear['lgbtqia'].apply(normalizar_texto)
print(f'\nNormalização "lgbtqia" feita com sucesso:\n')


# Dicionário de mapeamento para status de aprovacao
mapeamento = {
    'nao': 'Não',
    'acredito da liberdade de genero mas nao participo': 'Não',
    'respeito a todos e tenho amigos na comunidade, mais sou mulher.': 'Não',

   'sim': 'Sim',
    'simpatizante': 'Sim',
    'simpatizante e respeito as suas escolhas.': 'Sim', # Atenção ao ponto final aqui também após a normalização
    'digamos eu sou mas tenho renunciado por causa da minha fe': 'Sim',
    'sou bi isso inclui': 'Sim',


'prefiro nao responder': 'Prefiro não responder',
    'prefiro nao dizer': 'Prefiro não responder',
    'prefiro nao falar': 'Prefiro não responder',
    'nao sei': 'Prefiro não responder',
    'no formulario não ha pergunta sobre deficiencia: tenho tea nivel 1 de suporte': 'Prefiro não responder'




}
dataFlyClear['lgbtqia'] = dataFlyClear['lgbtqia'].replace(mapeamento)
print('\n✅ Agrupamento por palavras-chave realizado com sucesso!\n')
print(dataFlyClear['lgbtqia'].value_counts())
# Out:
# lgbtqia
# Não                                                                               1558
# Sim                                                                                646
# Prefiro não responder                                                               12
# Simpatizante                                                                         2
# Prefiro não dizer                                                                    1
# Simpatizante e respeito as suas escolhas                                             1
# Prefiro não responder                                                                1
# Prefiro não falar                                                                    1
# Acredito da liberdade de genero mas nao participo                                    1
# Não sei                                                                              1
# digamos, eu sou, mas tenho renunciado por causa da minha fé.                         1
# Respeito a todos e tenho amigos na comunidade, mais sou mulher.                      1
# No formulário não há pergunta sobre deficiência: tenho TEA nível  1 de suporte       1
# Sou Bi, isso inclui??                                                                1
# Name: count, dtype: int64
#
# Normalização "lgbtqia" feita com sucesso:
#
#
# ✅ Agrupamento por palavras-chave realizado com sucesso!
#
# lgbtqia
# Não                      1560
# Sim                       651
# Prefiro não responder      17
# Name: count, dtype: int64

# %%
print(dataFlyClear['raca_etnia'].value_counts())
# Out:
# raca_etnia
# Preta                             1035
# Parda                              797
# Branca                             444
# Indígena                            50
# Amarela                             15
# Negra                                1
# Afro descendente                     1
# Não sei                              1
# não sei                              1
# Etnia: Como você se identifica       1
# Cabocla                              1
# Name: count, dtype: int64

# %%
print("--- ANTES ---")
print(dataFlyClear['raca_etnia'].value_counts())

# Criação das máscaras com variações de acentuação e grafia
mask_branca = dataFlyClear['raca_etnia'].str.contains('branca', na=False, case=False)
mask_preta = dataFlyClear['raca_etnia'].str.contains('preta|Afro descendente|negra', na=False, case=False)
mask_amarela = dataFlyClear['raca_etnia'].str.contains('amarela', na=False, case=False)
mask_parda = dataFlyClear['raca_etnia'].str.contains('parda|cabloca|cabocla', na=False, case=False) # Adicionado 'cabocla'
mask_indigena = dataFlyClear['raca_etnia'].str.contains('indigina|indigena', na=False, case=False)
mask_naosei = dataFlyClear['raca_etnia'].str.contains('nao sei|não sei|etnia: Como você se identifica', na=False, case=False) # Adicionado 'não sei'

# Aplicando as alterações usando as máscaras criadas
dataFlyClear.loc[mask_branca, 'raca_etnia'] = 'Branca'
dataFlyClear.loc[mask_preta, 'raca_etnia'] = 'Preta'
dataFlyClear.loc[mask_amarela, 'raca_etnia'] = 'Amarela'
dataFlyClear.loc[mask_parda, 'raca_etnia'] = 'Parda'
dataFlyClear.loc[mask_indigena, 'raca_etnia'] = 'Indígena'
dataFlyClear.loc[mask_naosei, 'raca_etnia'] = 'Não sei'

print('\n✅ Agrupamento por raca_etnia realizado com sucesso!\n')
print("--- DEPOIS ---")
print(dataFlyClear['raca_etnia'].value_counts())
# Out:
# --- ANTES ---
# raca_etnia
# Preta                             1035
# Parda                              797
# Branca                             444
# Indígena                            50
# Amarela                             15
# Negra                                1
# Afro descendente                     1
# Não sei                              1
# não sei                              1
# Etnia: Como você se identifica       1
# Cabocla                              1
# Name: count, dtype: int64
#
# ✅ Agrupamento por raca_etnia realizado com sucesso!
#
# --- DEPOIS ---
# raca_etnia
# Preta       1037
# Parda        798
# Branca       444
# Indígena      50
# Amarela       15
# Não sei        3
# Name: count, dtype: int64

# %%
print(dataFlyClear['idade'].value_counts())
# Out:
# idade
# 27          89
# 25          83
# 29          81
# 22          76
# 24          74
# 28          73
# 20          72
# 37          71
# 26          68
# 30          66
# 31          65
# 21          64
# 23          61
# 33          59
# 36          58
# 32          57
# 34          57
# 42          56
# 19          51
# 39          50
# 41          48
# 38          48
# 43          47
# 35          45
# 45          45
# 44          42
# 40          40
# 18          37
# 17          35
# 47          27
# 49          26
# 46          25
# 52          21
# 16          20
# 48          17
# 50          17
# 53          15
# 51          15
# 54          12
# 55           9
# 56           8
# 0            7
# 58           6
# 59           5
# 15           4
# 62           4
# 63           3
# 66           3
# 57           2
# 60           2
# 64           2
# 14           1
# 65           1
# 67           1
# 4            1
# 162          1
# 71           1
# 27081982     1
# Name: count, dtype: Int64

# %%
# 1. Apliquei o filtro de limpeza diretamente no seu DataFrame principal
# Isso garante que todos os comandos abaixo usem apenas os dados limpos
dataFlyRaw = dataFlyRaw[(dataFlyRaw['idade'] >= 15) & (dataFlyRaw['idade'] <= 100)].copy()

# 2. Agora o código pode prosseguir com a certeza de que os dados estão limpos
print(dataFlyRaw['idade'].value_counts())

# Exemplo de criação de faixas etárias fixas
bins = [0, 19, 25, 35, 100]
labels = ['Até 19 anos', '20 a 25 anos', '26 a 35 anos', 'Mais de 35 anos']

# Criando a nova coluna com as categorias
dataFlyRaw['faixa_etaria'] = pd.cut(dataFlyRaw['idade'], bins=bins, labels=labels, right=True)

# 3. O qcut agora vai funcionar corretamente porque os outliers foram removidos
dataFlyRaw['quartil_idade'], limites = pd.qcut(
    dataFlyRaw['idade'],
    q=4,
    labels=['Q1 (Mais jovens)', 'Q2', 'Q3', 'Q4 (Mais velhos)'],
    retbins=True
)

# Para ver quais foram os cortes exatos gerados agora:
print("Limites dos quartis:", limites)

# Para ver quantos alunos caíram em cada faixa
print(dataFlyRaw['quartil_idade'].value_counts())
# Out:
# idade
# 27    89
# 25    83
# 29    81
# 22    76
# 24    74
# 28    73
# 20    72
# 37    71
# 26    68
# 30    66
# 31    65
# 21    64
# 23    61
# 33    59
# 36    58
# 32    57
# 34    57
# 42    56
# 19    51
# 39    50
# 41    48
# 38    48
# 43    47
# 35    45
# 45    45
# 44    42
# 40    40
# 18    37
# 17    35
# 47    27
# 49    26
# 46    25
# 52    21
# 16    20
# 48    17
# 50    17
# 53    15
# 51    15
# 54    12
# 55     9
# 56     8
# 58     6
# 59     5
# 62     4
# 15     4
# 63     3
# 66     3
# 60     2
# 64     2
# 57     2
# 65     1
# 67     1
# 71     1
# Name: count, dtype: Int64
# Limites dos quartis: [15. 24. 31. 40. 71.]
# quartil_idade
# Q2                  525
# Q1 (Mais jovens)    494
# Q3                  485
# Q4 (Mais velhos)    460
# Name: count, dtype: int64

# %%
#Como verificar o quão crítico é o desbalanceamento em % e em numeros reais da tabela
print(dataFlyRaw['pcd'].value_counts(normalize=True))
print(dataFlyClear['pcd'].value_counts())
# Out:
# pcd
# Não    0.957739
# Sim    0.042261
# Name: proportion, dtype: float64
# pcd
# Não                                   2122
# Sim                                     99
# Você é uma pessoa com deficiência?       1
# Name: count, dtype: int64

# %%
# Limpeza: Transformar tudo em 0 (Não) ou 1 (Sim)
# Usamos .map para garantir que só existam esses dois valores
# O fillna(0) garante que se algo estiver vazio, vira "Não" (0)
# valores diferentes poque apliquei um filtro na coluna idade explicação :  Quando um aluno tem uma linha corrompida (como idade 162 anos ou data
#de nascimento no lugar da idade), os outros dados dele naquela mesma linha (como PCD, notas, etc.) também não são confiáveis. O filtro de idade limpa a linha inteira,
#garantindo que o seu modelo de Machine Learning aprenda apenas com dados limpos, consistentes e reais.

dataFlyRaw['pcd'] = dataFlyRaw['pcd'].map({'Sim': 1, 'Não': 0}).fillna(0).astype(int)

# 2. Conferência:
print("Distribuição após limpeza:")
print(dataFlyRaw['pcd'].value_counts())
# Out:
# Distribuição após limpeza:
# pcd
# 0    1881
# 1      83
# Name: count, dtype: int64

# %%
print(dataFlyClear['pcd_tipo'].value_counts())
# Out:
# pcd_tipo
# Não me enquadro como PCD                                                                                                                                   767
# Prefiro não declarar                                                                                                                                        31
# Física                                                                                                                                                      22
# Intelectual                                                                                                                                                 13
# Auditiva                                                                                                                                                     5
# Múltipla                                                                                                                                                     3
# Visual                                                                                                                                                       2
# Não altera. É uma deficiência física.                                                                                                                        1
# Não tenho carteira de pcd porém possuo uma síndrome do desfiladeiro torácico e possuo documentação que comprove..mas ela não altera meu aprendizado!         1
# Sou autista pre diagnosticada e monocular ( enxergo apenas com o olho direito )                                                                              1
# Autista                                                                                                                                                      1
# 148.415.344-82                                                                                                                                               1
# Sim. TDAH.                                                                                                                                                   1
# Artrite reumatóide                                                                                                                                           1
# Deficiência auditiva- não altera o aprendizado.                                                                                                              1
# TDAH                                                                                                                                                         1
# Tenho Fibromialgia e as vezes ela altera minha concentração por conta da fadiga e dores.                                                                     1
# Nao                                                                                                                                                          1
# Você é uma pessoa com deficiência? Caso, sim, nos conte sobre, principalmente se ela altera o seu aprendizado. Caso não, deixe em branco esta pergunta.      1
# Fibromialgia, mobilidade reduzida, não altera o meu aprendizado.                                                                                             1
# não se aplica                                                                                                                                                1
# \n                                                                                                                                                           1
# .                                                                                                                                                            1
# Não                                                                                                                                                          1
# Motora                                                                                                                                                       1
# Tenho uma pequena diferença em uma perna                                                                                                                     1
# Name: count, dtype: int64

# %%
print(dataFlyClear['pcd_impacto_aprendizagem'].value_counts())
# Out:
# pcd_impacto_aprendizagem
# Não                                                                       134
# Sim                                                                         7
# Não                                                                         4
# Eu demoro as vezes pra conseguir entender as coisas, por conta do TEA.      1
# Psicosocial. Sou autista com dupla excepcionalidade                         1
#                                                                          ...
# Tenho problemas de visão , uma doença deformativa da córnea                 1
# Em nada                                                                     1
# Síndrome sinostosis racubital                                               1
# Fibromialgia                                                                1
# Apenas em parte, com material ampliado pode facilitar meus estudos          1
# Name: count, Length: 69, dtype: int64

# %%
print(dataFlyClear['escolaridade'].value_counts())
# Out:
# escolaridade
# Ensino Superior Completo (Graduação)      609
# Ensino Superior Incompleto (Graduação)    597
# Ensino Médio Completo                     453
# Pós-graduação                             252
# Ensino Técnico Completo                   100
# Ensino Médio Incompleto                    98
# Ensino superior completo                   64
# Ensino Técnico Incompleto                  45
# Ensino superior em andamento               43
# Ensino Fundamental Completo                36
# Ensino Fundamental Incompleto              20
# Ensino médio completo                      13
# Mestrado                                   11
# Ensino médio incompleto                     5
# Grau de Escolaridade                        1
# Name: count, dtype: int64

# %%
# 1. Padronizar o texto: transforma tudo em minúsculo e remove espaços extras
dataFlyRaw['escolaridade_limpa'] = dataFlyRaw['escolaridade'].astype(str).str.strip().str.lower()

# 2. Dicionário para unificar variações e agrupar em grandes blocos
mapeamento_escolaridade = {
    'ensino fundamental incompleto': 'Ensino Fundamental',
    'ensino fundamental completo': 'Ensino Fundamental',

    'ensino médio incompleto': 'Ensino Médio',
    'ensino médio completo': 'Ensino Médio',

    'ensino técnico incompleto': 'Ensino Técnico',
    'ensino técnico completo': 'Ensino Técnico',

    'ensino superior incompleto (graduação)': 'Ensino Superior',
    'ensino superior completo (graduação)': 'Ensino Superior',
    'ensino superior completo': 'Ensino Superior',
    'ensino superior em andamento': 'Ensino Superior',

    'pós-graduação': 'Pós-Graduação / Mestrado',
    'mestrado': 'Pós-Graduação / Mestrado'
}

# 3. Aplicar o mapeamento (valores que não encaixarem viram 'Outros')
dataFlyRaw['escolaridade_agrupada'] = dataFlyRaw['escolaridade_limpa'].map(mapeamento_escolaridade).fillna('Outros')

# 4. Conferir o resultado da nova coluna agrupada
print(dataFlyRaw['escolaridade_agrupada'].value_counts())
# Out:
# escolaridade_agrupada
# Ensino Superior             1082
# Ensino Médio                 474
# Pós-Graduação / Mestrado     228
# Ensino Técnico               136
# Ensino Fundamental            44
# Name: count, dtype: int64

# %%
print(dataFlyClear['estado_residencia'].value_counts())
print(dataFlyClear['estado_residencia'].nunique())
# Conta as frequências
freq_estado = dataFlyClear['estado_residencia'].value_counts()
# Out:
# estado_residencia
# São Paulo (SP)          508
# Rio de Janeiro (RJ)     396
# Pernambuco (PE)         187
# Bahia (BA)              141
# Santa Catarina (SC)     105
#                        ...
# Ceara                     1
# Rio de janeiro            1
# Tocantins                 1
# Rio grande do Norte       1
# Estado que mora:          1
# Name: count, Length: 96, dtype: int64
# 96

# %%
dataFlyClear.iloc[1292]
#Caso encontrado em estado Estado que mora?
mask_header_estado = dataFlyClear['estado_residencia'].str.contains('Estado que mora', na=False)
 #Visualiza essas linhas (se houver mais de uma)
linhas_sujas = dataFlyClear[mask_header_estado]
print(f"🔍 Encontradas {len(linhas_sujas)} linhas com cabeçalho vazado:")
display(linhas_sujas)  # ou print(linhas_sujas)
 #Remove as linhas que correspondem à máscara (cabeçalho vazado)
dataFlyClear = dataFlyClear[~mask_header_estado]

# Reseta o índice para ficar sequencial (0, 1, 2, ...)
dataFlyClear = dataFlyClear.reset_index(drop=True)

print(f"✅ Linha removida! Agora o DataFrame tem {dataFlyClear.shape[0]} linhas.")
# Out:
# 🔍 Encontradas 1 linhas com cabeçalho vazado:
#      nome_completo status_aprovacao genero lgbtqia raca_etnia  idade  \
# 1292    Aluna 1293              NaN    NaN     NaN    Não sei   <NA>
#
#                                      pcd  \
# 1292  Você é uma pessoa com deficiência?
#
#                                                pcd_tipo  \
# 1292  Você é uma pessoa com deficiência? Caso, sim, ...
#
#                                pcd_impacto_aprendizagem          escolaridade  \
# 1292  Caso sim para a pergunta acima, nos conte sobr...  Grau de Escolaridade
#
#       ... experiencia_programacao linguagem_programacao experiencia_dados  \
# 1292  ...                    None                  None              None
#
#      dataset_inconsistente_acao bibliotecas_ferramentas_utilizadas  \
# 1292                       None                               None
#
#       git_github_uso link_projeto_perfil projeto_dados_ia_descricao  \
# 1292            None                None                       None
#
#      dataset_evasao_interpretacao leitura_edital
# 1292                         None           None
#
# [1 rows x 91 columns]
# ✅ Linha removida! Agora o DataFrame tem 2347 linhas.

# %%
print(dataFlyClear['estado_residencia'].value_counts())
#apply = aplicar, aplicando a função na coluna
dataFlyClear['estado_residencia'] = dataFlyClear['estado_residencia'].apply(normalizar_texto)
print(f'\nNormalização "estado_residencia" feita com sucesso:\n')

# Dicionário de mapeamento para estado de residencia
mapeamento = {
    # Acre
    'acre (ac)': 'Acre (AC)',
    'acre': 'Acre (AC)',
    'ac': 'Acre (AC)',

    # Alagoas
    'alagoas (al)': 'Alagoas (AL)',
    'alagoas': 'Alagoas (AL)',
    'al': 'Alagoas (AL)',

    # Amapá
    'amapa (ap)': 'Amapa (AP)',
    'amapa': 'Amapa (AP)',
    'ap': 'Amapa (AP)',

    # Amazonas
    'amazonas (am)': 'Amazonas (AM)',
    'amazonas': 'Amazonas (AM)',
    'am': 'Amazonas (AM)',
    'ama': 'Amazonas (AM)',

    # Bahia
    'bahia (ba)': 'Bahia (BA)',
    'bahia': 'Bahia (BA)',
    'ba': 'Bahia (BA)',

    # Ceará
    'ceara (ce)': 'Ceara (CE)',
    'ceara': 'Ceara (CE)',
    'ce': 'Ceara (CE)',

    # Distrito Federal
    'distrito federal (df)': 'Distrito Federal (DF)',
    'distrito federal': 'Distrito Federal (DF)',
    'df': 'Distrito Federal (DF)',

    # Espírito Santo
    'espirito santo (es)': 'Espirito Santo (ES)',
    'espirito santo': 'Espirito Santo (ES)',
    'es': 'Espirito Santo (ES)',

    # Goiás
    'goias (go)': 'Goias (GO)',
    'goias': 'Goias (GO)',
    'go': 'Goias (GO)',

    # Maranhão
    'maranhao (ma)': 'Maranhao (MA)',
    'maranhao': 'Maranhao (MA)',
    'ma': 'Maranhao (MA)',

    # Mato Grosso
    'mato grosso (mt)': 'Mato Grosso (MT)',
    'mato grosso': 'Mato Grosso (MT)',
    'mt': 'Mato Grosso (MT)',

    # Mato Grosso do Sul
    'mato grosso do sul (ms)': 'Mato Grosso do Sul (MS)',
    'mato grosso do sul': 'Mato Grosso do Sul (MS)',
    'ms': 'Mato Grosso do Sul (MS)',

    # Minas Gerais
    'minas gerais (mg)': 'Minas Gerais (MG)',
    'minas gerais': 'Minas Gerais (MG)',
    'mg': 'Minas Gerais (MG)',

    # Pará
    'para (pa)': 'Para (PA)',
    'para': 'Para (PA)',
    'pa': 'Para (PA)',

    # Paraíba
    'paraiba (pb)': 'Paraiba (PB)',
    'paraiba': 'Paraiba (PB)',
    'pb': 'Paraiba (PB)',

    # Paraná
    'parana (pr)': 'Parana (PR)',
    'parana': 'Parana (PR)',
    'pr': 'Parana (PR)',

    # Pernambuco
    'pernambuco (pe)': 'Pernambuco (PE)',
    'pernambuco': 'Pernambuco (PE)',
    'pernambucano': 'Pernambuco (PE)',
    'pernanbuco': 'Pernambuco (PE)',
    'pe': 'Pernambuco (PE)',

    # Piauí
    'piaui (pi)': 'Piaui (PI)',
    'piaui': 'Piaui (PI)',
    'pi': 'Piaui (PI)',

    # Rio de Janeiro
    'rio de janeiro (rj)': 'Rio de Janeiro (RJ)',
    'rio de janeiro': 'Rio de Janeiro (RJ)',
    'rj': 'Rio de Janeiro (RJ)',

    # Rio Grande do Norte
    'rio grande do norte (rn)': 'Rio Grande do Norte (RN)',
    'rio grande do norte': 'Rio Grande do Norte (RN)',
    'rn': 'Rio Grande do Norte (RN)',

    # Rio Grande do Sul
    'rio grande do sul (rs)': 'Rio Grande do Sul (RS)',
    'rio grande do sul': 'Rio Grande do Sul (RS)',
    'rs': 'Rio Grande do Sul (RS)',

    # Rondônia
    'rondonia (ro)': 'Rondonia (RO)',
    'rondonia': 'Rondonia (RO)',
    'ro': 'Rondonia (RO)',

    # Roraima
    'roraima (rr)': 'Roraima (RR)',
    'roraima': 'Roraima (RR)',
    'rr': 'Roraima (RR)',

    # Santa Catarina
    'santa catarina (sc)': 'Santa Catarina (SC)',
    'santa catarina': 'Santa Catarina (SC)',
    'sc': 'Santa Catarina (SC)',

    # São Paulo
    'sao paulo (sp)': 'São Paulo (SP)',
    'sao paulo': 'São Paulo (SP)',
    'solteira': 'São Paulo (SP)', # provável erro de preenchimento de cidade
    'sp': 'São Paulo (SP)',

    # Sergipe
    'sergipe (se)': 'Sergipe (SE)',
    'sergipe': 'Sergipe (SE)',
    'se': 'Sergipe (SE)',

    # Tocantins
    'tocantins (to)': 'Tocantins (TO)',
    'tocantins': 'Tocantins (TO)',
    'to': 'Tocantins (TO)',

    # Caso especial: Fora do Brasil
    'fora do brasil': 'Fora do Brasil',
}
# Aplica o mapeamento
dataFlyClear['estado_residencia'] = dataFlyClear['estado_residencia'].replace(mapeamento)
print('✅ "São Paulo", "Sao paulo" agora são a mesma categoria!\n')
print(dataFlyClear['estado_residencia'].value_counts())
# Out:
# estado_residencia
# São Paulo (SP)          508
# Rio de Janeiro (RJ)     396
# Pernambuco (PE)         187
# Bahia (BA)              141
# Santa Catarina (SC)     105
#                        ...
# Ceara                     1
# Para                      1
# Rio de janeiro            1
# Tocantins                 1
# Rio grande do Norte       1
# Name: count, Length: 95, dtype: int64
#
# Normalização "estado_residencia" feita com sucesso:
#
# ✅ "São Paulo", "Sao paulo" agora são a mesma categoria!
#
# estado_residencia
# São Paulo (SP)              516
# Rio de Janeiro (RJ)         401
# Pernambuco (PE)             314
# Bahia (BA)                  186
# Ceara (CE)                  124
# Santa Catarina (SC)         105
# Para (PA)                    71
# Amazonas (AM)                51
# Maranhao (MA)                48
# Paraiba (PB)                 48
# Minas Gerais (MG)            42
# Piaui (PI)                   35
# Rio Grande do Norte (RN)     35
# Goias (GO)                   31
# Roraima (RR)                 23
# Parana (PR)                  20
# Rio Grande do Sul (RS)       18
# Sergipe (SE)                 17
# Distrito Federal (DF)        16
# Rondonia (RO)                15
# Alagoas (AL)                 11
# Amapa (AP)                   10
# Espirito Santo (ES)           8
# Tocantins (TO)                7
# Acre (AC)                     4
# Mato Grosso (MT)              3
# Fora do Brasil                2
# Name: count, dtype: int64

# %%
print(dataFlyClear['cidade_residencia'].value_counts())
#apply = aplicar, aplicando a função na coluna
dataFlyClear['cidade_residencia'] = dataFlyClear['cidade_residencia'].apply(normalizar_texto)
print(f'\nNormalização "cidade_residencia" feita com sucesso:\n')

# Dicionário de mapeamento para cidade de residencia
mapeamento = {
    # São Paulo
    'sao paulo': 'São Paulo',
    'sao paulo (sp)': 'São Paulo',
    'sp': 'São Paulo',

    # Rio de Janeiro
    'rio de janeiro': 'Rio de Janeiro',
    'rio de janeiro (rj)': 'Rio de Janeiro',
    'rio de janeiro - rj': 'Rio de Janeiro',
    'rj': 'Rio de Janeiro',

    # Salvador
    'salvador': 'Salvador',
    'salvador (ba)': 'Salvador',
    'salvador ba': 'Salvador',
    'salvador': 'Salvador',
    'salvdor': 'Salvador',

    # Recife
    'recife': 'Recife',
    'recife (pe)': 'Recife',
    'recife, pe': 'Recife',
    'recife': 'Recife',
    'recife (pe)': 'Recife',
    'recife, pe': 'Recife',
    'recife': 'Recife',

    # Manaus
    'manaus': 'Manaus',
    'manáos': 'Manaus',
    'manaus (am)': 'Manaus',

    # Outras cidades identificadas
    'itaquaquecetuba': 'Itaquaquecetuba',
    'jaboatao dos guararapes': 'Jaboatão dos Guararapes',
    'uberlandia': 'Uberlândia',
    'olinda': 'Olinda',
    'itaperuna': 'Itaperuna',
    'palmas': 'Palmas',
    'chapeco': 'Chapecó',
    'chapoco': 'Chapecó',
    'brasilia (df)': 'Brasília',
    'brasilia': 'Brasília',
    'ouro branco': 'Ouro Branco',
    'viamao': 'Viamao',
    'petrolina': 'Petrolina',
    'valinhos': 'Valinhos',
    'cruzeiro': 'Cruzeiro',
    'florianopolis': 'Florianopolis',
    'santarem': 'Santarém',
    'santarem': 'Santarém',
    'londrina- pr': 'Londrina',
    'santo antonio do descoberto': 'Santo Antonio do Descoberto',
    'curitiba': 'Curitiba',
    'grajau': 'Grajau',
}
# Aplica o mapeamento
dataFlyClear['cidade_residencia'] = dataFlyClear['cidade_residencia'].replace(mapeamento)
print('✅ "São Paulo", "Sao paulo" agora são a mesma categoria!\n')
print(dataFlyClear['cidade_residencia'].value_counts())
# Out:
# cidade_residencia
# São Paulo         231
# Rio de Janeiro    168
# Salvador           47
# Rio de janeiro     32
# Recife             22
#                  ...
# Itaperuna           1
# Palmas              1
# Chapecó             1
# Recife, PE          1
# Manáos              1
# Name: count, Length: 469, dtype: int64
#
# Normalização "cidade_residencia" feita com sucesso:
#
# ✅ "São Paulo", "Sao paulo" agora são a mesma categoria!
#
# cidade_residencia
# São Paulo                      280
# Rio de Janeiro                 245
# Salvador                        52
# Florianopolis                   33
# Recife                          28
#                               ...
# Valinhos                         1
# Santarém                         1
# Londrina                         1
# Santo Antonio do Descoberto      1
# Grajau                           1
# Name: count, Length: 343, dtype: int64

# %% [markdown]
# ## Análises da coluna X

# %%
# Inspeção específica da coluna - Trocar o nome da coluna a analisar
coluna = 'status_aprovacao'

if coluna in dataFlyClear.columns:
    # Dados básicos
    total_linhas = len(dataFlyClear)
    n_nulos = dataFlyClear[coluna].isna().sum()
    pct_nulos = (n_nulos / total_linhas) * 100
    n_unicos = dataFlyClear[coluna].nunique()

    # Exibe as informações
    print(f"\n{'='*50}")
    print(f"📊 ANÁLISE DA COLUNA: {coluna.upper()}")
    print(f"{'='*50}")
    print(f"Total de linhas:          {total_linhas}")
    print(f"Valores nulos:            {n_nulos} ({pct_nulos:.2f}%)")
    print(f"Valores não-nulos:        {total_linhas - n_nulos}")
    print(f"Valores únicos:           {n_unicos}")

    # Distribuição de frequência (os mais comuns)
    print(f"\n📈 Distribuição de frequência:")
    print(dataFlyClear[coluna].value_counts().head(10))

    # Se houver nulos, mostra quantas linhas têm nulo e dica
    if n_nulos > 0:
        print(f"\n⚠️  Esta coluna tem {n_nulos} registros sem informação.")
    else:
        print(f"\n✅ Esta coluna está 100% preenchida! Nenhum nulo.")
else:
    print(f"❌ Coluna '{coluna}' não encontrada no DataFrame.")
# Out:
# ==================================================
# 📊 ANÁLISE DA COLUNA: STATUS_APROVACAO
# ==================================================
# Total de linhas:          2347
# Valores nulos:            1177 (50.15%)
# Valores não-nulos:        1170
# Valores únicos:           3
#
# 📈 Distribuição de frequência:
# status_aprovacao
# Não aprovada    1004
# Formada          100
# Aprovada          66
# Name: count, dtype: int64
#
# ⚠️  Esta coluna tem 1177 registros sem informação.

# %%
df = dataFlyClear

for col in df.columns:
    n_nulos = df[col].isna().sum()
    n_unicos = df[col].nunique()
    exemplos = df[col].dropna().unique()[:5]
    print(f"\n--- {col} ---")
    print(f"nulos: {n_nulos}/{len(df)} | valores únicos: {n_unicos}")
    print("exemplos:", list(exemplos))
# Out:
# --- nome_completo ---
# nulos: 0/2347 | valores únicos: 2347
# exemplos: ['Aluna 1', 'Aluna 2', 'Aluna 3', 'Aluna 4', 'Aluna 5']
#
# --- status_aprovacao ---
# nulos: 1177/2347 | valores únicos: 3
# exemplos: ['Formada', 'Não aprovada', 'Aprovada']
#
# --- genero ---
# nulos: 118/2347 | valores únicos: 3
# exemplos: ['Mulher cisgênero', 'Mulher Transgênero', 'Não-Binário']
#
# --- lgbtqia ---
# nulos: 119/2347 | valores únicos: 3
# exemplos: ['Sim', 'Não', 'Prefiro não responder']
#
# --- raca_etnia ---
# nulos: 1/2347 | valores únicos: 6
# exemplos: ['Preta', 'Parda', 'Branca', 'Indígena', 'Amarela']
#
# --- idade ---
# nulos: 372/2347 | valores únicos: 58
# exemplos: [np.int64(22), np.int64(0), np.int64(45), np.int64(35), np.int64(37)]
#
# --- pcd ---
# nulos: 126/2347 | valores únicos: 2
# exemplos: ['Não', 'Sim']
#
# --- pcd_tipo ---
# nulos: 1486/2347 | valores únicos: 25
# exemplos: ['Não tenho carteira de pcd porém possuo uma síndrome do desfiladeiro torácico e possuo documentação que comprove..mas ela não altera meu aprendizado!', 'Sou autista pre diagnosticada e monocular ( enxergo apenas com o olho direito )', 'Não altera. É uma deficiência física.', 'Tenho Fibromialgia e as vezes ela altera minha concentração por conta da fadiga e dores.', 'TDAH']
#
# --- pcd_impacto_aprendizagem ---
# nulos: 2137/2347 | valores únicos: 68
# exemplos: ['Não', 'Sim', 'Psicosocial. Sou autista com dupla excepcionalidade', 'Eu demoro as vezes pra conseguir entender as coisas, por conta do TEA.', 'Psicossocial e não altera o aprendizado.']
#
# --- escolaridade ---
# nulos: 1/2347 | valores únicos: 14
# exemplos: ['Ensino Superior Completo (Graduação)', 'Ensino Médio Completo', 'Ensino Superior Incompleto (Graduação)', 'Ensino Técnico Incompleto', 'Ensino Técnico Completo']
#
# --- estado_residencia ---
# nulos: 186/2347 | valores únicos: 27
# exemplos: ['São Paulo (SP)', 'Pernambuco (PE)', 'Rio de Janeiro (RJ)', 'Maranhao (MA)', 'Ceara (CE)']
#
# --- cidade_residencia ---
# nulos: 922/2347 | valores únicos: 343
# exemplos: ['sao carlos', 'São Paulo', 'sao joao de meriti', 'guarulhos', 'teresina']
#
# --- como_conheceu_mulheres_in_tech ---
# nulos: 1195/2347 | valores únicos: 130
# exemplos: ['Redes sociais de parceiros  (Stem para Minas, Inspira Sonha, Tech...)', 'Indicação de professor/ coordenador / escola', 'Instagram da Fly', 'Indicação de amigos', 'Linkedin da Fly']
#
# --- processo_seletivo_anterior ---
# nulos: 1808/2347 | valores únicos: 7
# exemplos: ['Não', 'Sim', 'Mulheres In Tech', 'Semente', 'Empreende  Fly']
#
# --- processo_seletivo_anterior_detalhe ---
# nulos: 2346/2347 | valores únicos: 1
# exemplos: ['Não lembro']
#
# --- qtd_pessoas_casa ---
# nulos: 705/2347 | valores únicos: 16
# exemplos: [np.int64(3), np.int64(8), np.int64(7), np.int64(2), np.int64(5)]
#
# --- renda_familiar_pessoa ---
# nulos: 1/2347 | valores únicos: 8
# exemplos: ['Menos de 1 salário mínimo por pessoa', 'De 1 a 2 salários mínimos por pessoa', 'De 3 a 5 salários mínimos por pessoa', 'Mais de 5 salários mínimos por pessoa', 'Entre 2 e 3 salários mínimos']
#
# --- renda_propria ---
# nulos: 1142/2347 | valores únicos: 9
# exemplos: ['Menos de 1 salário mínimo', 'Menos de 1 salário mínimo por pessoa', 'Não tenho renda', 'De 1 a 2 salários mínimos', 'De 3 a 5 salários mínimos']
#
# --- renda_principal_fonte_casa ---
# nulos: 1161/2347 | valores únicos: 2
# exemplos: ['Não', 'Sim']
#
# --- situacao_profissional_atual ---
# nulos: 693/2347 | valores únicos: 19
# exemplos: ['Não estou trabalhando e estou procurando oportunidade', 'Trabalho autônomo / empreendedorismo', 'Trabalhando de carteira assinada sem ser na área que deseja', 'Trabalhando de carteira assinada na área que deseja', 'Estou em transição de carreira']
#
# --- situacao_financeira_casa ---
# nulos: 819/2347 | valores únicos: 1516
# exemplos: ['No momento só o meu pai esta trabalhando, minha mãe e eu estamos procurando algo tbm pra poder ajudar ele com as despesas, mas por enquanto só ele quem trabalha. Minha irmã tem 12 anos então ela só estuda mesmo.', 'no momento estou desempregada, somente o meu filho mais velho que esta trabalhando', 'Trabalho como diarista e cuidadora , não tenho renda fixa', 'Eu trabalho na feira como comerciante minha filha faz tranças em casa e meu marido está desempregado', 'Moro sozinha, vivo atualmente com ajuda de custo do governo bolsa família e sou autônoma, faço todo tipo de free lance e me viro com oque consigo na minha carreira com a música e como dreadmaker']
#
# --- interesse_dev_web ---
# nulos: 1706/2347 | valores únicos: 7
# exemplos: ['Sim, estudo por conta própria', 'Sim, mas nunca tive contato com a área', 'Sim, estudo em uma instituição formal', 'Sim, estudei em uma instituição formal', 'Sim, trabalho atualmente na área']
#
# --- possui_computador ---
# nulos: 878/2347 | valores únicos: 2
# exemplos: ['Sim', 'Não']
#
# --- possui_wifi ---
# nulos: 1718/2347 | valores únicos: 2
# exemplos: ['Sim', 'Não']
#
# --- disponibilidade_quarta_noite ---
# nulos: 1834/2347 | valores únicos: 2
# exemplos: ['Sim', 'Não']
#
# --- disponibilidade_mentoria_semanal ---
# nulos: 1834/2347 | valores únicos: 2
# exemplos: ['Sim', 'Não']
#
# --- disponibilidade_tempo_estudo ---
# nulos: 818/2347 | valores únicos: 7
# exemplos: ['3 a 5 horas por dia', '1 a 2 horas por dia', 'Mais de 5 horas por dia', 'Somente aos finais de semana', '3 horas ou mais por dia']
#
# --- turma ---
# nulos: 1142/2347 | valores únicos: 5
# exemplos: ['Turma 11 - Mulheres Pretas', 'Turma 17 - MIT Norte e Nordeste', 'Turma 15 - Breu Branco e região', 'Turma 14 - MIT Norte e Nordeste', 'Turma 10 - Nordeste']
#
# --- coluna_vazia ---
# nulos: 2347/2347 | valores únicos: 0
# exemplos: []
#
# --- turma_aba ---
# nulos: 0/2347 | valores únicos: 8
# exemplos: ['T10_11_14_15_17', 'T12', 'T16', 'T18', 'T19']
#
# --- refugiada_imigrante ---
# nulos: 2047/2347 | valores únicos: 3
# exemplos: ['Não', 'Sim, refugiada', 'Sim, imigrante']
#
# --- refugiada_pais ---
# nulos: 2204/2347 | valores únicos: 32
# exemplos: ['Brasil', '-', 'Angola(Migrantes)', 'Argentina', 'BRASIL']
#
# --- interesse_ia_gestao ---
# nulos: 2231/2347 | valores únicos: 7
# exemplos: ['Sim, estudo por conta própria', 'Sim, mas nunca tive contato com a área', 'Sim, trabalho atualmente na área', 'Sim, estudo em uma instituição formal', 'Sim, já trabalhei na área']
#
# --- justificativa_interesse ---
# nulos: 2171/2347 | valores únicos: 176
# exemplos: ['Decidi fazer transição de carreira para tecnologia e agregar valor ao que já sei na área de gestão ao longo desse anos. Mas, não é fácil. Sonhei em reservar um valor para investimento nessa área. Consultei a plataforma Alura ainda e garimpo sempre à procura de formações em tecnologia. Mas, o que recebo só dá para pagar as despesas. Não tem sido simples a vida. Contudo, tenho tanta força dentro de mim que sou chamada de sonhadora. Àquela garota de 13 anos que lavava roupa no rio porque não tinha água encanada em casa se formou na área educacional, se especializou e despertou a vontade de ir além. Quando vi o programa, meus olhos brilharam. É tudo que preciso nesse momento, o conteúdo do programa parece ter sido criado para mim.', 'Tenho muito interesse para minha vida profissional, até mesmo para o empreendedorismo', 'Há um tempo tenho o desejo de fazer a transição de carreira para área de tecnologia, pois é uma área que me atrai muito, tenho muita curiosidade em aprender mais sobre e trabalhar na área', 'Eu atuou em uma empresa de tecnologia e vejo como é difícil as mulheres conseguirem cargos de gestão e liderança. Quero ter a possibilidade de ser uma mulher negra com um cargo de liderança. Quero sim aprender IA e ter uma carreira que possa impactar pessoas e abrir caminhos para outras mulheres.', 'Trabalho na área de TI após realizar transição de carreira e me identifico muito com a área de gestão e liderança tech. Não conheço muitas mulheres em condição de liderança, menos ainda pretas, e queria poder crescer nessa área e servir como inspiração para mulheres que possam vir a me ter como referência']
#
# --- expectativa_mentoria ---
# nulos: 1331/2347 | valores únicos: 1001
# exemplos: ['Vejo que uma boa líder é feita de muitas mãos. Amo aprender. Amo ouvir pessoas e uma pessoa que esteja disposta a compartilhar seus conhecimentos já é maravilhoso. Uma mentoria que me auxilie a realizar uma disrupção, destravar meu modo criativo e inovador seria genial.', 'Eu estou disposta a conhecer o projeto , que nunca tive curiosidade', 'É muito bom ter alguém com experiência pra te dar um norte , me sentiria lisonjeada em ter esse apoio. A mentoria ideal seria alguém que pudesse passar seus conhecimentos e sua experiência profissional e de vida comigo, alguém que se tornasse também uma grande amiga.', 'Eu acredito que é muito bom aprender com mulheres que já atuam na área, que podem nos mostrar o caminho das pedras, mulheres que nos inspiram, fornece direcionamento e nos ajudam a alinhar nossos planos.', 'Eu gosto de uma mentoria mais prática, com objetivos definidos para um determinado prazo, em que podemos fazer um acompanhamento mais próximo e mais focado na parte técnica']
#
# --- percepcao_pedir_ajuda ---
# nulos: 1331/2347 | valores únicos: 960
# exemplos: ['Pedir ajuda não é sinal de fraqueza. Pedir ajuda é autoconhecimento. Só uma pessoa que enxerga suas fraquezas e identifica que não consegue sozinha, pede ajuda. Para mim é muito tranquilo isso.', 'Eu espero que vocês me ajudem muito em relação ao conhecimento ao projeto', 'Na vida sempre precisaremos um dos outros então me sinto tranquila sobre isso e como mencionei acima é ótimo ser orientada por alguém com experiência e que possa ajudar.', 'Eu não tenho problema em pedir ajuda, isso faz parte do meu dia a dia, sempre peço ajuda quando não sei algo.', 'Eu tinha muito problema em pedir ajuda antes de fazer transição de carreira, pois me sentia muito insegura e tinha medo de me expressar. Hoje estou bem mais confortável com isso e acho a troca com outras pessoas essencial no meu dia a dia.']
#
# --- experiencia_autodidata ---
# nulos: 1331/2347 | valores únicos: 978
# exemplos: ['Essa é fácil. Meu curso de Pedagogia, apesar de ter sido numa universidade pública, foi EAD. Fiz uma graduação inteira via moodle e tive que desenvolver a disciplina, o foco e gestão do tempo para entregar todas as atividades em tempo hábil.', 'Faço inglês e estou saindo bem', 'Já realizei cursos on-line e obtive êxito nos meus estudos,  conseguindo aproveitar e aprender o conteúdo estudado.', 'Na transição da minha carreira de Direito para área de tecnologia eu estudei e ainda estudo sozinha para conseguir entrar na área, deu certo, faz 2 anos que fiz essa transição.', 'Acho que minha vida inteira eu fui autodidata, pois sempre me interesso por coisas diferentes e nunca tive condições financeiras, então tinha que me virar como podia. Acho que o caso que mais deu certo em minha vida foi realizar a migração de carreira pra TI pois mesmo fazendo bootcamp e tendo aulas, a maior parte dos conhecimentos que conseguimos na área é puramente pesquisa, estudo e ser autodidata.']
#
# --- experiencia_positiva_conclusao ---
# nulos: 1331/2347 | valores únicos: 1000
# exemplos: ['Minha graduação e pós. Tenho 3 pós, uma em especial foi desafiante já que foi em área que não tinha tanta habilidade. A experiência positiva foi que acabei sendo destaque na Jornada de Líderes da empresa e fui promovida à época.', 'Fiz um curso técnico,nunca imaginei na área e hoje sou apaixonada ,em busca de uma vaga de trabalho', 'Além dos cursos tem a faculdade e pós graduação que consegui finalizar com êxito.', 'Sempre procuro terminar o que início, acho importante para atingir as metas da minha vida. A faculdade é um curso que iniciei e terminei, alguns cursos livres para área de tecnologia também comecei e terminei.', 'Eu já terminei muitas coisas, sou Bacharel em Biologia, possuo duas graduações e terminei dois bootcamps de tecnologia e acho que as coisas que mais me motivam a chegar até o fim é poder ser uma referência. Fui a primeira pessoa da minha família a entrar numa faculdade pública e me formar nela, e desde então eu sou muito motivada a ser uma das primeiras e poder abrir portas para as outras mulheres que venham depois e provar que tudo é possível']
#
# --- experiencia_negativa_nao_conclusao ---
# nulos: 1331/2347 | valores únicos: 1001
# exemplos: ['Tenho um curso de história incompleto por causa de trabalho. Não consegui entregar o TCC final. Fiz praticamente tudo, mas por ser presencial não consegui associar as duas atividades. Tinha que ganhar o pão.', 'Muito raro eu não conseguir finalizar algo que já comecei ,sou muito focada', 'Já fiz um curso onde desisti de finalizar, pois não tinha suporte pra sanar minhas dúvidas, não tinha um bom retorno do professor na época.', 'Comecei a fazer um curso presencial, no entanto precisei mudar de cidade e não consegui terminar.', 'Acho que minhas experiências que eu não tenha finalizado possam ser as que não me deram aquele incentivo ou interesse em continuar. Como eu gosto de fazer diversas coisas e sou uma pessoa muito movida a curiosidade e estimulada por desafios, quando algo é maçante, eu acabo priorizando outras que me dêem essa maior carga de desafios que gosto de ter']
#
# --- diferenca_entre_experiencias ---
# nulos: 1332/2347 | valores únicos: 991
# exemplos: ['Faltou planejamento. Talvez uma conversa franca com minha liderança para que abrisse mão daquele horário e pagasse em outro. Mas o Enzo nasceu nesse interim também. Foi difícil. Como tem sido agora em fazer transição de carreira. Um super desafio.', 'Nunca tive', 'O suporte do curso conta muito ,muito mais na hora das dúvidas que precisamos tirar.', 'A falta de acessibilidade (por ser presencial) me fez desistir do curso.', 'Acho que tanto o fato de querer muito algo como também o fato de ficar engajada e curiosa. Sou movida pela curiosidade e não gosto de ficar sem fazer algo ou ficar em algo que não me instigue a curiosidade.']
#
# --- confianca_concluir_programa ---
# nulos: 1331/2347 | valores únicos: 993
# exemplos: ['Tenho o tempo e a rotina a meu favor. As condições ideiais para realizar esse programa como não teria em outro momento.', 'Sou muito focada quando começo a fazer uma coisa', 'A vontade de aprender sobre a área, já tentei entrar em outros programas de tecnologia , mas não consegui a vaga ainda, mas continuarei tentando até conseguir a oportunidade', 'Eu quero me tornar líder e acredito que o conteúdo do curso irá me ajudar bastante, quando queremos algo precisamos ser perseverante para terminar e fazer nosso melhor.', 'Quero muito me tornar uma pessoa referência na área principalmente para mulheres de grupos subrepresentados poderem ver em mim alguém em que se espelhar. Além de ter esse objetivo em mente, acho a área de IA e Gestão duas áreas muito interessantes e com coisas inovadoras que instigam minha curiosidade, o que me deixa motivada e consequentemente me incentiva a finalizar']
#
# --- rotina_semanal_descricao ---
# nulos: 1331/2347 | valores únicos: 1012
# exemplos: ['Acordo às 07 h da manhã e organizo a casa no período da manhã. Levo o meu garoto para a escola que funciona das 14 às 18. Nesse interim aproveito para estudar. Ao fim da tarde saio para fazer uma caminhada, preparo o jantar e curto a família. Assisto, me dedico ao Enzo e ao Robson. Quando dá, saímos. Mas, utilizamos mesmo é o fim de semana para sair da rotina e visitar os amigos e parentes.', 'Eu acordo às 5 da manhã, faço café da manhã,saiu para trabalhar as 6:10 hrs para pegar o ônibus 6:20 hrs , pego no trabalho as 7 hrs da manhã , como estou fazendo um trabalho freelance só trabalho 6 hrs por dia , numa empresa terceirizada, chego em casa às 14 hrs da tarde , almoço, descanso, faço minhas coisas em casa . Normalmente não saiu , fico em casa com meu esposo , um fim de semana e outro saímos , encontramos amigos e familiares, almoçamos, jantamos com eles', 'No momento minha rotina está com tempo, pois tive bebê e encontro-me na licença maternidade , por esse motivo estou em busca de me aperfeiçoar e estudar enquanto me encontro nesse tempo de licença maternidade.', 'Acordo às 05h30, preparo café da manhã para mim e minha família, as 06h50 levo meu filho para escola. 07h00 as 07h50 faço curso de inglês, 08h00 livre. 09h00 início o trabalho até às 18h00. 18h30 as 19h30 preparar o jantar. 20h00 estudos 22h00 preparação para dormir 23h hora que vou dormir.', 'Geralmente acordo às 07:30 e começo a trabalhar às 08:30, trabalho home office. Trabalho até por volta das 12:30 e faço meu próprio almoço durante a semana. Volto a trabalhar por volta das 13:30 e largo às 18/18:30. Eu faço terpaia semanalmente às segundas-feiras e meus hobbies são principalmente relacionados a arte (costurar, pintar, ler, cinema, etc) e também gosto de jogos online. Geralmente a noite eu assisto aulas da faculdade EAD ou algum curso que eu tenha adquirido.']
#
# --- encaixe_horas_estudo_rotina ---
# nulos: 1331/2347 | valores únicos: 1009
# exemplos: ['Pretendo utilizar o período da tarde para isso. Além de utilizar a noite, quando meu filho dormir.', 'Vou tirar todos os dias as 17 hrs para poder estudar, como já faço um pouco de inglês,irei fazer com a mentoria também', 'Pretendo estudar na parte da manhã cedo ou da noite que é mais tranquilo e a bebê dorme bem  , acho que seria um horário ideal para focar  nos estudos.', 'Irei estudar das 20h00 as 22h00 horas que eu disponibilizo para os estudos.', 'Pretendo definir dias e horários específicos no meu dia para estudos do curso e intercalar com os conteúdos da faculdade.']
#
# --- motivo_escolha_candidata ---
# nulos: 1331/2347 | valores únicos: 1015
# exemplos: ['Porque sou comprometida, criativa, sou responsável, tenho sede por tecnologia e estou com 43 anos. É agora. O meu tempo é hoje. Nunca tive tão ciente disso como agora.', 'Prefiro não responder', 'Acho q a maternidade recente me deu mais vontade e força pra ir em buscar de uma vida melhor pra minha família, eles que me motivam a buscar o melhor.', 'Serei comprometida com o curso, para realmente conseguir ingressar em um cargo de gestão e com essa oportunidade que eu tive proporcionar oportunidades para outras mulheres. Assim o meu maior objetivo com o curso e conhecimentos adquiridos é que isso não pare em mim e sim que eu possa ajudar  outras mulheres.', 'Eu responderia que eu deveria ser escolhida pois sou uma pessoa multidisciplinar e também possuo minhas soft skills bem desenvolvidas, precisando apenas focar mais em hard skills e direcionar mais minha jornada rumo à gestão']
#
# --- compromisso_criterios_certificado ---
# nulos: 1216/2347 | valores únicos: 4
# exemplos: ['Sim', 'Não tenho certeza ainda', 'Não', 'Preciso pensar']
#
# --- ciencia_investimento_vaga ---
# nulos: 1206/2347 | valores únicos: 201
# exemplos: ['Sim', 'Sim, estou.', 'Sim. Estou ciente', 'Sim, por isso darei o meu máximo.', 'Sim, estou ciente disso. Entendo que esse curso representa um investimento significativo, tanto em termos de tempo quanto de recursos financeiros, e respeito totalmente o compromisso envolvido. Caso eu  seja aceita, estou totalmente dedicada a aproveitar ao máximo a oportunidade e garantir que esse investimento não seja desperdiçado. Tenho plena consciência da importância dessa vaga e do apoio das pessoas e empresas que a tornam possível, e pretendo honrar esse compromisso com seriedade e empenho.']
#
# --- doacao_mensal_voluntaria ---
# nulos: 1331/2347 | valores únicos: 15
# exemplos: ['Eu consigo apoiar com uma doação mensal de R$ 10 x 12 (R$ 120,00 no ano)', 'Eu consigo apoiar com uma doação mensal de R$ 15 x 12 (R$ 180,00 no ano)', 'De momento, não consigo apoiar com nenhuma doação mensal', 'Eu consigo apoiar com uma doação mensal de R$ 50 x 12 (R$ 600,00 no ano)', 'Eu consigo apoiar com uma doação mensal de R$ 5 x 12 (R$ 60,00 no ano)']
#
# --- email ---
# nulos: 2347/2347 | valores únicos: 0
# exemplos: []
#
# --- coluna_sem_nome ---
# nulos: 1800/2347 | valores únicos: 233
# exemplos: [np.float64(17.0), np.float64(45.0), np.float64(20.0), np.float64(39.0), np.float64(70.0)]
#
# --- orientacao_sexual ---
# nulos: 1507/2347 | valores únicos: 6
# exemplos: ['Heterosexual', 'Bissexual', 'Homosexual', 'Prefiro não responder', 'Outro']
#
# --- refugiada ---
# nulos: 1507/2347 | valores únicos: 2
# exemplos: ['Não', 'Sim']
#
# --- conhecimento_probabilidade ---
# nulos: 1959/2347 | valores únicos: 4
# exemplos: ['Não tenho conhecimento nessa área de estudo', 'Sou iniciante nessa área de estudo', 'Tenho nível de conhecimento intermediário nessa área de estudo', 'Tenho conhecimento avançado nessa área de estudo']
#
# --- evidencia_conhecimento_probabilidade ---
# nulos: 2141/2347 | valores únicos: 185
# exemplos: ['Estou começando nessa área agora, estou um pouco perdida do que estudar ou não.', 'Faculdade em Análise e desenvolvimento de Sistemas', 'Estudei na graduação', 'Trabalho com engenharia de dados', 'Iniciei alguns estudos na área do Design Gráfico há 4 anos (durante a pandemia), gostei muito e fui aperfeiçoando várias habilidades de lá para cá, enquanto também cursava Nutrição. No ínicio de 2024, decidi começar, de fato, uma transição de carreira, por me estar me identificando muito mais com a área de tecnologia. Tenho muito interesse nas possibilidades de atuação como designer dentro dessa nova área, venho estudando (por meio de cursos gratuitos) experiência do usuário e criação de interfaces, mas ainda não tenho certificados que possam me destacar em vagas de emprego, etc. Visando essa entrada no mundo tech, quero também ter conhecimentos sobre programação (mesmo sendo básicos), pois quero me diferenciar enquanto designer e acredito no poder dos estudos como forma de crescer e ter mais oportunidades na carreira.']
#
# --- conhecimento_estatistica ---
# nulos: 1959/2347 | valores únicos: 4
# exemplos: ['Não tenho conhecimento nessa área de estudo', 'Sou iniciante nessa área de estudo', 'Tenho nível de conhecimento intermediário nessa área de estudo', 'Tenho conhecimento avançado nessa área de estudo']
#
# --- evidencia_conhecimento_estatistica ---
# nulos: 2166/2347 | valores únicos: 163
# exemplos: ['Mesma da anterior', 'Estudei na graduação', 'Tenho conhecimentos básicos de estatística, apenas o necessário para realizar processos seletivos, como o ENEM, ou seja: conhecimentos de ensino médio. Nunca precisei me aprofundar nisso antes.', 'Fiz o curso de python para análise de dados e lá estudei assuntos como esse', 'Sim']
#
# --- conhecimento_algebra_linear ---
# nulos: 1959/2347 | valores únicos: 4
# exemplos: ['Não tenho conhecimento nessa área de estudo', 'Sou iniciante nessa área de estudo', 'Tenho nível de conhecimento intermediário nessa área de estudo', 'Tenho conhecimento avançado nessa área de estudo']
#
# --- evidencia_conhecimento_algebra_linear ---
# nulos: 2199/2347 | valores únicos: 127
# exemplos: ['Mesma resposta', 'Estudei na graduação', 'Tenho menos conhecimento aqui do que em estatística, mas, novamente, apenas conhecimentos básicos de ensino médio. Nunca precisei me aprofundar nisso antes.', 'Sim', 'Não']
#
# --- possui_internet ---
# nulos: 1507/2347 | valores únicos: 2
# exemplos: ['Sim', 'Não']
#
# --- conhecimento_ia ---
# nulos: 2023/2347 | valores únicos: 4
# exemplos: ['Tenho nível de conhecimento intermediário nessa área de estudo', 'Sou iniciante nessa área de estudo', 'Não tenho conhecimento nessa área de estudo', 'Tenho conhecimento avançado nessa área de estudo']
#
# --- evidencia_conhecimento_ia ---
# nulos: 2151/2347 | valores únicos: 182
# exemplos: ['Sou técnico de informática,  fiz minha faculdade no meu país. ', 'Pesquisa de internet ', 'Eu fiz um curso sobre IA na escola conquer', 'Trabalhei como designer instrucional e fazia o GIT das imagens no VC e já fiz curso de html.', 'A atualidade']
#
# --- filhos_cuidadora ---
# nulos: 2060/2347 | valores únicos: 2
# exemplos: ['Sim', 'Não']
#
# --- regiao_residencia ---
# nulos: 2219/2347 | valores únicos: 3
# exemplos: ['Grande Florianópolis', 'Nordeste', 'Norte']
#
# --- evidencia_conhecimento_dev_web ---
# nulos: 2283/2347 | valores únicos: 49
# exemplos: ['Sim, faço o curso de desenvolvimento web da IFRS.', 'fiz umas aulas no Cisco Networking Academy mas não acabei o curso ', 'Participei de duas conferência sobre IA, com soi David no Instagram, E atualmente estou fazendo um curso virtual sobre marketing digital, mas estou apenas começando.', 'Não tenho evidência', 'Estou trabalhando de auxiliar de É-comerce na parte de marketing é desarrollo das páginas Web dos site para empresa para a que trabalho ']
#
# --- data_nascimento ---
# nulos: 2165/2347 | valores únicos: 151
# exemplos: [Timestamp('1970-01-01 00:00:00.000000017'), Timestamp('1970-01-01 00:00:00.000000044'), Timestamp('1970-01-01 00:00:00.000000016'), Timestamp('1970-01-01 00:00:00.000000018'), Timestamp('1970-01-01 00:00:00.000000030')]
#
# --- nacionalidade ---
# nulos: 2162/2347 | valores únicos: 14
# exemplos: ['Brasileira ', 'Brasileira', 'Brasileiro ', 'Não sei ', 'Brasil ']
#
# --- estado_civil ---
# nulos: 2287/2347 | valores únicos: 17
# exemplos: ['Solteira ', 'Solteiro ', 'Casada', 'Solteira', 'solteira ']
#
# --- endereco_completo ---
# nulos: 2163/2347 | valores únicos: 183
# exemplos: ['Bairro: Liberdade Rua: Olinda Cavalcante Número:50', 'Rua Maranhao, 190 Centro ', 'Bairro liberdade numero 07 casa dois andar rua reginaldo bom fim cep 6848800 ', 'RUA PRIMEIRO DE MAIO, NUMERO 19 BAIRRO BELA VISTA, CIDADE BREU BRANCO -PA CEP 68488000', 'Cep: 68488-000 / Estado: Pará / Cidade:Breu Branco/ Bairro:Novo Horizonte/ Rua parauapebas / N 123']
#
# --- profissao ---
# nulos: 2287/2347 | valores únicos: 45
# exemplos: ['Não tenho', 'Auxiliar de secretaria ', 'Nenhuma', 'Estudante', 'estudante ']
#
# --- pcd_necessita_adaptacao ---
# nulos: 2344/2347 | valores únicos: 2
# exemplos: ['Sim', 'Não']
#
# --- estado_nascimento ---
# nulos: 2287/2347 | valores únicos: 9
# exemplos: ['Pará (PA)', 'Distrito Federal (DF)', 'Maranhão (MA)', 'Minas Gerais (MG)', 'Rio de Janeiro (RJ)']
#
# --- relacao_breu_branco ---
# nulos: 2287/2347 | valores únicos: 9
# exemplos: ['Sou natural de Breu Branco e moro atualmente na cidade', 'Moro atualmente em Breu Branco, mas sou de outra cidade', 'Não sou natural e não moro em Breu Branco', 'Há vinte anos moro em Breu Branco.', 'Sou natural de Breu Branco, mas moro em outra cidade']
#
# --- como_conheceu_mulheres_in_tech_como_foi ---
# nulos: 2300/2347 | valores únicos: 45
# exemplos: ['Da minha professora Helena', 'Amiga Helena ', 'Professora Helena soares', 'Professora Heloisa Helena da Escola Severo Alves ', 'Professora Helena Soares/ Escola Servero Alves']
#
# --- relacao_marketing_digital ---
# nulos: 2287/2347 | valores únicos: 6
# exemplos: ['Nunca tive contato com a área, mas tenho interesse', 'Tenho curiosidade e acompanho conteúdos sobre o tema', 'Estudo ou já estudei em uma instituição formal', 'Trabalho atualmente na área', 'Aplico o marketing digital nos meus próprios negócios ou projetos']
#
# --- dispositivos_disponiveis ---
# nulos: 2162/2347 | valores únicos: 11
# exemplos: ['Celular/Smartphone', 'Notebook', 'Celular/Smartphone, Notebook', 'Celular/Smartphone, Tablet', 'Celular/Smartphone, Tablet, Notebook']
#
# --- forma_acesso_internet ---
# nulos: 2287/2347 | valores únicos: 3
# exemplos: ['Wi-Fi em casa', 'Wi-Fi de terceiros (escola, trabalho, centros públicos, comércio)', 'Dados móveis próprios (3G/4G/5G)']
#
# --- situacao_carreira_atual ---
# nulos: 2287/2347 | valores únicos: 5
# exemplos: ['Estou buscando oportunidades', 'Não estou buscando oportunidades no momento', 'Atuando fora da área que desejo', 'Atuando na área que desejo', 'Estou em transição de carreira']
#
# --- apoio_politicas_publicas ---
# nulos: 2287/2347 | valores únicos: 5
# exemplos: ['Sim, estudei sempre em escola pública', 'Sim, estudei parte da vida em escola pública', 'Sim, com bolsa ou apoio (ex: Prouni, FIES, etc.)', 'Não tive acesso a nenhuma política pública', 'Não. Estudei em escola particular']
#
# --- interrupcao_estudos ---
# nulos: 2287/2347 | valores únicos: 6
# exemplos: ['Não', 'Sim, por motivos financeiros', 'Sim, por cuidado com familiares', 'Sim, por questões de saúde', 'Sim, por trabalho ou jornada dupla']
#
# --- ocupacao ---
# nulos: 2223/2347 | valores únicos: 94
# exemplos: ['Analista de melhoria contínua ', 'Securitária', 'Estudante ', 'Analista de Transportes ', 'Especialista em Dados']
#
# --- tipo_escola_formacao ---
# nulos: 2222/2347 | valores únicos: 3
# exemplos: ['Parte pública / parte privada', 'Escola pública', 'Escola privada']
#
# --- disponibilidade_tempo_curso ---
# nulos: 2222/2347 | valores únicos: 3
# exemplos: ['Mais de 10 horas', '5 a 10 horas', 'Até 5 horas']
#
# --- experiencia_programacao ---
# nulos: 2222/2347 | valores únicos: 8
# exemplos: ['Já fiz cursos introdutórios', 'Nunca programei', 'Já escrevi pequenos scripts ou projetos simples', 'Já desenvolvi projetos mais estruturados', 'Já fiz cursos introdutórios, Já escrevi pequenos scripts ou projetos simples']
#
# --- linguagem_programacao ---
# nulos: 2227/2347 | valores únicos: 90
# exemplos: ['.', 'Nunca programei', 'Javascript', 'PHP, JavaScript , pyhon', 'HTML, css, javascript, python, SQL ']
#
# --- experiencia_dados ---
# nulos: 2222/2347 | valores únicos: 4
# exemplos: ['Já analisei dados em Excel ou Google Sheets', 'Nunca', 'Já usei Python ou outra linguagem para análise de dados', 'Já desenvolvi projetos de análise ou modelos']
#
# --- dataset_inconsistente_acao ---
# nulos: 2223/2347 | valores únicos: 122
# exemplos: ['Validação da fonte', 'Identificar quais campos estão incompletos (valores nulos, vazios ou faltantes).\nDetectar inconsistências', 'Analisar os dados, encontrar o erro e criar algum script para reescrever as informações corretas ', 'Verificar como os dados estão chegando ', 'Buscar a fonte de dados central para encontrar as informações faltantes. ']
#
# --- bibliotecas_ferramentas_utilizadas ---
# nulos: 2222/2347 | valores únicos: 24
# exemplos: ['Nenhuma', 'Pandas, Numpy, Google Colab / Jupyter Notebook', 'Google Colab / Jupyter Notebook', 'Google Colab / Jupyter Notebook, Visual Studio Code', 'Pandas, Numpy, Matplotlib ou Seaborn, Scikit-learn, Google Colab / Jupyter Notebook']
#
# --- git_github_uso ---
# nulos: 2222/2347 | valores únicos: 3
# exemplos: ['Já utilizei para baixar projetos', 'Nunca utilizei', 'Já publiquei ou organizei projetos em um repositório']
#
# --- link_projeto_perfil ---
# nulos: 2228/2347 | valores únicos: 94
# exemplos: ['.', 'Não aplicável', 'Não tenho ', 'https://ana-anaglebias-projects.vercel.app/#about-me', 'GitHub, mas apenas para aprovar PR para deploy']
#
# --- projeto_dados_ia_descricao ---
# nulos: 2224/2347 | valores únicos: 115
# exemplos: ['Implementação da métrica de aderência para os operadores de cobrança ', ' desenvolvimento de um sistema de triagem e análise inteligente de processos judiciais repetitivos.', 'Estou com uma ideia de construir um aplicativo para usar em máquinas de snacks', 'Gosto de trabalhar com bando de dados. Trazer informacors', 'Como trabalho na logística e presencio diariamente as dores de algumas ferramentas que não tem sido tão eficazes, gostaria de executar algo que tivesse mais assertividade para uma alocação automática de rota para os drivers, no qual avalie a performance e a região de entrega, fazendo um rodízio justo com a quantidade de drivers x rotas disponíveis. ']
#
# --- dataset_evasao_interpretacao ---
# nulos: 2260/2347 | valores únicos: 83
# exemplos: ['Importante gerar dados qualitativos para entender o motivo da evasão de uma turma ser o dobro da evasão da outra turma.', 'a turma B apresentou melhor desempenho em termos de permanência dos alunos.', 'Um percentual maior de avasao  na turma B', 'Ainda n diz muita coisa, pois se trata de um Data Set, refinaria mais para ter algum tipo de diagnóstico, como por exemplo, retirada de nulos que podem estar enviesando a analise.', 'Que a turma A é menos estável, possui maior desengajamento ou enfrentou obstáculos mais significativos para a permanência dos alunos. Gestores pode focar ações de busca ativa e apoio pedagógico na turma A para equilibrar os índices de permanência.']
#
# --- leitura_edital ---
# nulos: 2223/2347 | valores únicos: 1
# exemplos: ['Sim']

# %%
#Criar Coluna target -> Olhar para status_aprovacao: Aprovada - Formada = Evasão

# %%
# Inspeção específica da coluna
coluna = 'cidade_residencia'

if coluna in dataFlyClear.columns:
    # Dados básicos
    total_linhas = len(dataFlyClear)
    n_nulos = dataFlyClear[coluna].isna().sum()
    pct_nulos = (n_nulos / total_linhas) * 100
    n_unicos = dataFlyClear[coluna].nunique()

    # Exibe as informações
    print(f"\n{'='*50}")
    print(f"📊 ANÁLISE DA COLUNA: {coluna.upper()}")
    print(f"{'='*50}")
    print(f"Total de linhas:          {total_linhas}")
    print(f"Valores nulos:            {n_nulos} ({pct_nulos:.2f}%)")
    print(f"Valores não-nulos:        {total_linhas - n_nulos}")
    print(f"Valores únicos:           {n_unicos}")

    # Distribuição de frequência (os mais comuns)
    print(f"\n📈 Distribuição de frequência:")
    print(dataFlyClear[coluna].value_counts().head(10))

    # Se houver nulos, mostra quantas linhas têm nulo e dica
    if n_nulos > 0:
        print(f"\n⚠️  Esta coluna tem {n_nulos} registros sem informação.")
    else:
        print(f"\n✅ Esta coluna está 100% preenchida! Nenhum nulo.")
else:
    print(f"❌ Coluna '{coluna}' não encontrada no DataFrame.")
# Out:
# ==================================================
# 📊 ANÁLISE DA COLUNA: CIDADE_RESIDENCIA
# ==================================================
# Total de linhas:          2347
# Valores nulos:            922 (39.28%)
# Valores não-nulos:        1425
# Valores únicos:           343
#
# 📈 Distribuição de frequência:
# cidade_residencia
# São Paulo         280
# Rio de Janeiro    245
# Salvador           52
# Florianopolis      33
# Recife             28
# sao jose           27
# osasco             20
# nova iguacu        20
# palhoca            18
# fortaleza          17
# Name: count, dtype: int64
#
# ⚠️  Esta coluna tem 922 registros sem informação.

# %% [markdown]
# ## Tipos

# %%
# Tipos (texto → número; extrair dígitos de textos como '28 anos'):
dataFlyClear['idade'] = dataFlyClear['idade'].astype(str).str.extract(r'(\d+)').astype('Int64')
print(dataFlyClear['idade'])
# Out:
# 0         22
# 1          0
# 2         45
# 3         35
# 4         37
#         ...
# 2342    <NA>
# 2343    <NA>
# 2344    <NA>
# 2345    <NA>
# 2346    <NA>
# Name: idade, Length: 2347, dtype: Int64

# %% [markdown]
# ## Nulos

# %%
print(f"Dados Nulos: {dataFlyClear.isnull().sum().sum()}")   # ideal: 0
porcentagem_nulos = (dataFlyClear.isnull().sum().sum() / (dataFlyClear.shape[0] * dataFlyClear.shape[1])) * 100
print(f"Porcentagem de nulos: {porcentagem_nulos:.2f}%")
# Out:
# Dados Nulos: 149115
# Porcentagem de nulos: 69.82%

# %%
# Nulos — escolha a estratégia por coluna:
# df['CATEGORICA'] = df['CATEGORICA'].fillna('Não informado')        # categórico: rótulo com sentido
# df['NUMERICA']   = df['NUMERICA'].fillna(df['NUMERICA'].median())  # número: mediana (robusta)
# df = df.dropna(subset=['COLUNA_ESSENCIAL'])                        # remove sem info essencial

# %%
# 👉 Confira ao final:
#print(f"Dados Nulos: {dataFlyClear.isnull().sum().sum()}")   # ideal: 0
#porcentagem_nulos = (dataFlyClear.isnull().sum().sum() / (dataFlyClear.shape[0] * dataFlyClear.shape[1])) * 100
#print(f"Porcentagem de nulos: {porcentagem_nulos:.2f}%")

# %% [markdown]
# ## Salvar e usar Parquet versão clear

# %%
## Salva a versão
#dataFlyClear.to_parquet('dataFlyClear.parquet', index=False, compression='gzip')
#print("Arquivo limpo salvo com sucesso!")
#dataFlyClear = pd.read_parquet('dataFlyClear.parquet')

# %% [markdown]
# ---
# # 🧩 4. Combinar fontes (montar a base de análise)
#
# > **Objetivo:** deixar a base na granularidade certa — **um caso por linha** (ex.: um aluno por linha).
# > **Pergunta-chave:** "o que é UMA linha aqui?" vs "o que precisa ser uma linha pra minha análise?"
# > **Consulte:** Guia HTML (seção "Combinar") para o passo a passo com exemplos.

# %%
# ── 4. COMBINAR ─────────────────────────────────────────────────────────────

# 4a) EMPILHAR arquivos com as MESMAS colunas (mais casos):
# base = pd.concat([df_2023, df_2024], ignore_index=True)

# 4b) AGRUPAR: mudar a granularidade (de muitas linhas por caso → 1 linha por caso).
#     Padrão:  nome_novo = ('coluna_original', 'conta')
# base_analise = df.groupby('CHAVE').agg(
#     coluna_fixa = ('COLUNA',   'first'),   # info que não muda por caso
#     total       = ('VALOR',    'sum'),     # soma
#     quantidade  = ('VALOR',    'count'),   # nº de linhas do grupo
#     media       = ('NUMERICA', 'mean'),    # média
#     minimo      = ('NUMERICA', 'min'),     # menor (ex.: pior frequência)
# ).reset_index()
# Contas úteis: sum, mean, median, count, nunique, min, max, first, last, std

# 4c) JUNTAR outra tabela pela CHAVE em comum (trazer mais colunas):
#     A CHAVE é a coluna que existe nas DUAS tabelas (ex.: 'municipio', um id, o CPF).
#     Ela precisa estar escrita igual e ser do mesmo tipo nos dois lados (padronize antes!).
# base_analise = base_analise.merge(TABELA_APOIO, on='CHAVE', how='left')
#   Tipos de join (how):
#     'left'  → mantém TODOS da tabela principal (o mais comum)
#     'inner' → só quem existe nas duas (descarta em silêncio — cuidado!)
#     'outer' → todos dos dois lados | 'right' → todos da direita
#   ⚠️ confira o nº de linhas ANTES e DEPOIS do merge (df.shape)!

# 4d) REMODELAR (visão cruzada, ótima pra virar heatmap):
# visao = df.pivot_table(index='LINHAS', columns='COLUNAS', values='VALOR', aggfunc='mean')

# 🔑 Ordem de ouro: empilhar → AGRUPAR (deixa a chave única) → juntar.

# %%
dataFlyRaw.shape
# Out:
# (1964, 95)

# %%
dataFlyRaw.head(3)
# Out:
#   nome_completo status_aprovacao            genero                lgbtqia  \
# 0       Aluna 1          Formada  Mulher cisgênero                    Sim
# 2       Aluna 3     Não aprovada  Mulher cisgênero                    Não
# 3       Aluna 4     Não aprovada  Mulher cisgênero  Prefiro não responder
#
#   raca_etnia  idade  pcd pcd_tipo pcd_impacto_aprendizagem  \
# 0      Preta     22    0     None                     None
# 2      Parda     45    0     None                      Não
# 3      Preta     35    0     None                      Não
#
#                              escolaridade  ...  \
# 0    Ensino Superior Completo (Graduação)  ...
# 2                   Ensino Médio Completo  ...
# 3  Ensino Superior Incompleto (Graduação)  ...
#
#   bibliotecas_ferramentas_utilizadas git_github_uso link_projeto_perfil  \
# 0                               None           None                None
# 2                               None           None                None
# 3                               None           None                None
#
#   projeto_dados_ia_descricao dataset_evasao_interpretacao  leitura_edital  \
# 0                       None                         None            None
# 2                       None                         None            None
# 3                       None                         None            None
#
#       faixa_etaria     quartil_idade                      escolaridade_limpa  \
# 0     20 a 25 anos  Q1 (Mais jovens)    ensino superior completo (graduação)
# 2  Mais de 35 anos  Q4 (Mais velhos)                   ensino médio completo
# 3     26 a 35 anos                Q3  ensino superior incompleto (graduação)
#
#   escolaridade_agrupada
# 0       Ensino Superior
# 2          Ensino Médio
# 3       Ensino Superior
#
# [3 rows x 95 columns]

# %%
list(dataFlyRaw.columns)
# Out:
# ['nome_completo',
#  'status_aprovacao',
#  'genero',
#  'lgbtqia',
#  'raca_etnia',
#  'idade',
#  'pcd',
#  'pcd_tipo',
#  'pcd_impacto_aprendizagem',
#  'escolaridade',
#  'estado_residencia',
#  'cidade_residencia',
#  'como_conheceu_mulheres_in_tech',
#  'processo_seletivo_anterior',
#  'processo_seletivo_anterior_detalhe',
#  'qtd_pessoas_casa',
#  'renda_familiar_pessoa',
#  'renda_propria',
#  'renda_principal_fonte_casa',
#  'situacao_profissional_atual',
#  'situacao_financeira_casa',
#  'interesse_dev_web',
#  'possui_computador',
#  'possui_wifi',
#  'disponibilidade_quarta_noite',
#  'disponibilidade_mentoria_semanal',
#  'disponibilidade_tempo_estudo',
#  'turma',
#  'coluna_vazia',
#  'turma_aba',
#  'refugiada_imigrante',
#  'refugiada_pais',
#  'interesse_ia_gestao',
#  'justificativa_interesse',
#  'expectativa_mentoria',
#  'percepcao_pedir_ajuda',
#  'experiencia_autodidata',
#  'experiencia_positiva_conclusao',
#  'experiencia_negativa_nao_conclusao',
#  'diferenca_entre_experiencias',
#  'confianca_concluir_programa',
#  'rotina_semanal_descricao',
#  'encaixe_horas_estudo_rotina',
#  'motivo_escolha_candidata',
#  'compromisso_criterios_certificado',
#  'ciencia_investimento_vaga',
#  'doacao_mensal_voluntaria',
#  'email',
#  'coluna_sem_nome',
#  'orientacao_sexual',
#  'refugiada',
#  'conhecimento_probabilidade',
#  'evidencia_conhecimento_probabilidade',
#  'conhecimento_estatistica',
#  'evidencia_conhecimento_estatistica',
#  'conhecimento_algebra_linear',
#  'evidencia_conhecimento_algebra_linear',
#  'possui_internet',
#  'conhecimento_ia',
#  'evidencia_conhecimento_ia',
#  'filhos_cuidadora',
#  'regiao_residencia',
#  'evidencia_conhecimento_dev_web',
#  'data_nascimento',
#  'nacionalidade',
#  'estado_civil',
#  'endereco_completo',
#  'profissao',
#  'pcd_necessita_adaptacao',
#  'estado_nascimento',
#  'relacao_breu_branco',
#  'como_conheceu_mulheres_in_tech_como_foi',
#  'relacao_marketing_digital',
#  'dispositivos_disponiveis',
#  'forma_acesso_internet',
#  'situacao_carreira_atual',
#  'apoio_politicas_publicas',
#  'interrupcao_estudos',
#  'ocupacao',
#  'tipo_escola_formacao',
#  'disponibilidade_tempo_curso',
#  'experiencia_programacao',
#  'linguagem_programacao',
#  'experiencia_dados',
#  'dataset_inconsistente_acao',
#  'bibliotecas_ferramentas_utilizadas',
#  'git_github_uso',
#  'link_projeto_perfil',
#  'projeto_dados_ia_descricao',
#  'dataset_evasao_interpretacao',
#  'leitura_edital',
#  'faixa_etaria',
#  'quartil_idade',
#  'escolaridade_limpa',
#  'escolaridade_agrupada']

# %% [markdown]
# ---
# # 📈 5. Explorar (EDA)
#
# > **Objetivo:** descobrir o que os dados dizem — resumos, comparações entre grupos e correlações.
# > **Consulte:** notebooks das aulas de EDA e estatística.

# %%
# ── 5. EXPLORAR (EDA) ───────────────────────────────────────────────────────

# Tendência central e dispersão (troque 'COLUNA' pela sua variável numérica):
# base_analise['COLUNA'].mean()      # média (sensível a outliers)
# base_analise['COLUNA'].median()    # mediana (mais honesta p/ renda, salário...)
# base_analise['COLUNA'].std()       # desvio-padrão (o quanto varia)

# Comparar um número entre categorias (o coração da EDA social):
# base_analise.groupby('CATEGORIA')['COLUNA'].median().sort_values()

# Correlação entre variáveis numéricas (-1 a +1):
# base_analise[['NUM1','NUM2','NUM3']].corr()
# ⚠️ Correlação NÃO é causa — nas conclusões, escreva "sugere", nunca "prova".

# %% [markdown]
# ---
# # 📊 6. Visualizar (fechar a EDA)
#
# > **Objetivo:** ver e contar a história. Escolha o gráfico certo pra cada pergunta.
# > **Consulte:** Guia HTML (miniaturas de cada gráfico) e a aula de visualização.

# %%
# ── 6. VISUALIZAR ───────────────────────────────────────────────────────────

# Histograma — distribuição de UMA variável:
# plt.hist(base_analise['COLUNA'], bins=30); plt.show()

# Boxplot — comparar grupos e ver outliers:
# sns.boxplot(data=base_analise, x='NUMERICA', y='CATEGORIA'); plt.show()

# Barras — comparar categorias:
# base_analise.groupby('CATEGORIA')['NUMERICA'].median().plot(kind='barh'); plt.show()

# Dispersão — duas numéricas se relacionam?
# plt.scatter(base_analise['NUM1'], base_analise['NUM2']); plt.show()

# Heatmap — várias correlações de uma vez:
# sns.heatmap(base_analise[['NUM1','NUM2','NUM3']].corr(), annot=True, cmap='RdBu_r', center=0); plt.show()

# 📖 Storytelling: título = conclusão · cor só no destaque · anote valores · uma ideia · cite a fonte.

# %% [markdown]
# ---
# # ✅ Checklist antes de entregar
#
# - [✅] **Carreguei** e olhei o `head()`
# - [✅] **Conheci** a base (`info`, `describe`, `isnull`, `value_counts`)
# - [✅] **Limpei** (duplicatas, texto padronizado, normalização, nulos, tipos)
# - [ ] **Combinei** na granularidade certa (um caso por linha) e conferi o nº de linhas nos merges
# - [ ] **Explorei** (médias/medianas, comparação entre grupos, correlação)
# - [ ] **Visualizei** com storytelling (título conclusivo, fonte)
# - [ ] Código formatado e indentado
# - [ ] Variáveis em camelCase
# - [ ] URLs, Strings, JSON com aspas duplas
# - [ ] Comentários claros em português
# - [ ] Teste de execução da célula
# - [ ] Sem dados sensíveis no código
# - [ ] Changelog atualizado
#
#
# **Orientadora:** [Andressa Freires - diversiData](https://www.linkedin.com/in/andressafreires/)
